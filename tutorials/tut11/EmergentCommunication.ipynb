# %% [markdown]
# Authors: Ran Harari and Adi Amuzig
# E-mails: [srharari@campus.technion.ac.il](srharari@campus.technion.ac.il),
#          [adi.amuzig@campus.technion.ac.il](mailto:adi.amuzig@campus.technion.ac.il)

# %% [markdown]
# # Emergent Communication
#
# Because the real world is dynamic and continually changing, many real-world scenarios demand coordination among different actors, and having a centralized system to oversee all actions is not possible in a large-scale environment.
#
# Furthermore, communication is quite beneficial in resolving the coordination challenge. In theory, we could simply transfer sensory data among robots, but this would be a lot of information that would be irrelevant because each unit will perceive the world differently owing to its location and sensors.
#
# The interaction between two agents with communication abilities follows a typical cycle with three levels: sensori-motor, conseptual, and language. The cycle is as follows:
#
# 1. **Grounding** - Both agents precive the world and creating a world model (sensori-motor level)
# 2. **Conceptualization** - The speaker determines which information is most useful to the listener in order for the mission to succeed and builds a semantic framework (conceptual level)
# 3. **Production** - conveying a message of semantic experience through verbal or implicit behaviors (language level)
# 4. **Comprehension** - The communication is received and analyzed by the listener into a semantic form (language level)
# 5. **Interpretation** - interpreting the semantic structure in reference to one's own world model and carrying out the appropriate action (conceptual level)
#
# ![Communication Cycle](images/emergent_com_theory.png)
# [A Practical Guide to Studying Emergent Communication through Grounded Language Games - Nevens, Eecke and Beuls]
#
# When it comes to communication, there are two primary options:
#
# - A pre-defined communication protocol, which means that all communication and the actions that occur from that communication are programmed into the system. Before the system goes live, all aspects of the communication cycle are fully specified.
# - Emergent communication is the study of how a communication system emerges among previously uncommunicative individuals. To put it another way, at least some components of the communication cycle must be learned. It is important to note that emergent communication necessitates many interactions between the same agent in order to *learn* a functional communication system.

# %% [markdown]
# ## The Importance of communication
#
# Communication in general is helpful in a multi-robot system for both robot cooperation and human robot collaboration. This session will concentrate on the former.
#
# To investigate the role of communication, we used the multitaxi domain to create a situation with no communication between the agents. To confirm that our communication strategy worked, we first solved the multitaxi domain without communication and demonstrated that it works.

# %%
import math

from src.Communication.COM_net import COM_net
from src.agents.agent import DecisionMaker, Action_message_agent, Agent_Com, RandomDecisionMaker
from src.control.Controller_COM import DecentralizedComController
from src.decision_makers.planners.map_planner import AstarDM
from src.environments.env_wrapper import EnvWrappper, TAXI_pickup_dropoff_REWARDS
from multi_taxi import MultiTaxiEnv



MAP2 = [
    "+-------+",
    "| : |F: |",
    "| : | : |",
    "| : : : |",
    "| | :G| |",
    "+-------+",
]

MAP = [
    "+-----------------------+",
    "| : |F: | : | : | : |F: |",
    "| : | : : : | : | : | : |",
    "| : : : : : : : : : : : |",
    "| : : : : : | : : : : : |",
    "| : : : : : | : : : : : |",
    "| : : : : : : : : : : : |",
    "| | :G| | | :G| | | : | |",
    "+-----------------------+",
]

"""
Builds Multi_taxi env
"""
env = MultiTaxiEnv(num_taxis=2, num_passengers=2, domain_map=MAP, observation_type='symbolic')

env.seed(0)

obs = env.reset()

def build_multi_env(env):
    env.agents = env.taxis_names
    env.action_spaces = {
        agent_name: env.action_space for agent_name in env.agents
    }
    env.observation_spaces = {
        agent_name: env.observation_space for agent_name in env.agents
    }
    env.possible_agents = [agent for agent in env.agents]
    return EnvWrappper(env, env.agents)


environment = build_multi_env(env)
print('EnvironmentWrapper created')

"""
COM-agent - we will explain later
"""

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker : AstarDM , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = True):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None

    def set_data_func(self, obs):
        data = (self.decision_maker.taking_passenger,len(self.decision_maker.active_plan))
        return data

    # todo - implement your recive_func
    def set_recive_func(self, obs, message):
        pass

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action

"""
part 1 - 
agents sends com but dont use it - A-star DM solves for each agent
"""
# after having our com-Astar-agents class we can set our env agents into a dicentralized_agents dict
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(AstarDM(env ,single_plan=True, Taxi_index=int(agent_name[-1]), domain_map=MAP) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}


"""
COM-module - we will explain later
"""
com = COM_net()
""" 
    - MAC controller 
"""
controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
controller.run(render=True, max_iteration=15)
print("Thats all - part 1")
# Out:
# EnvironmentWrapper created
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : :P: : | : : :D: : |
# | : : : : : | : : : :_: |
# |_: : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,0), Collided: False
# Passenger1: Location: (0, 10), Destination: (3, 9)
# Passenger2: Location: (3, 3), Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# active:['(1,)', '(1,)', '(1,)', '(1,)', '(4,)', '(0,)', '(0,)', '(3,)', '(0,)', '(5,)']
# all plans:[['(1,)', '(1,)', '(1,)', '(1,)', '(4,)', '(0,)', '(0,)', '(3,)', '(0,)', '(5,)'], ['(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(0,)', '(4,)', '(1,)', '(1,)', '(2,)', '(6,)']]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : :P: : | : : :D: : |
# | : : : : : | : : : :_: |
# |_: : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,0), Collided: False
# Passenger1: Location: (0, 10), Destination: (3, 9)
# Passenger2: Location: (3, 3), Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# active:['(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(4,)', '(1,)', '(1,)', '(2,)', '(6,)']
# all plans:[['(1,)', '(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(1,)', '(1,)', '(4,)', '(0,)', '(0,)', '(3,)', '(0,)', '(5,)'], ['(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(4,)', '(1,)', '(1,)', '(2,)', '(6,)']]
# ---------------------------ROUND 1---------------------------------
# taxi_0 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 1
# taxi_1 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 1
# joint Message: [(1, 9), (2, 9)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : :P: : | : : :D:_: |
# |_: : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,0), Collided: False
# Passenger1: Location: (0, 10), Destination: (3, 9)
# Passenger2: Location: (3, 3), Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# ---------------------------ROUND 2---------------------------------
# taxi_0 obs:
#  [ 3 10  0 10  3  3  3  9  1  4  2  2  1  9  2  9] , action: 1
# taxi_1 obs:
#  [ 4  0  0 10  3  3  3  9  1  4  2  2  1  9  2  9] , action: 1
# joint Message: [(1, 8), (2, 8)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : :_: |
# |_: : :P: : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,0), Collided: False
# Passenger1: Location: (0, 10), Destination: (3, 9)
# Passenger2: Location: (3, 3), Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# ---------------------------ROUND 3---------------------------------
# taxi_0 obs:
#  [ 2 10  0 10  3  3  3  9  1  4  2  2  1  8  2  8] , action: 1
# taxi_1 obs:
#  [ 3  0  0 10  3  3  3  9  1  4  2  2  1  8  2  8] , action: 2
# joint Message: [(1, 7), (2, 7)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : :D: | : | : |_: |
# | : : : : : : : : : : : |
# | :_: :P: : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,1), Collided: False
# Passenger1: Location: (0, 10), Destination: (3, 9)
# Passenger2: Location: (3, 3), Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# ---------------------------ROUND 4---------------------------------
# taxi_0 obs:
#  [ 1 10  0 10  3  3  3  9  1  4  2  2  1  7  2  7] , action: 1
# taxi_1 obs:
#  [ 3  1  0 10  3  3  3  9  1  4  2  2  1  7  2  7] , action: 2
# joint Message: [(1, 6), (2, 6)]
# +-----------------------+
# | : |F: | : | : | : |P: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : :_:P: : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,2), Collided: False
# Passenger1: Location: (0, 10), Destination: (3, 9)
# Passenger2: Location: (3, 3), Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [2, 2]
# ---------------------------ROUND 5---------------------------------
# taxi_0 obs:
#  [ 0 10  0 10  3  3  3  9  1  4  2  2  1  6  2  6] , action: 4
# taxi_1 obs:
#  [ 3  2  0 10  3  3  3  9  1  4  2  2  1  6  2  6] , action: 2
# joint Message: [(1, 5), (2, 5)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : :P: : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,3), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 9)
# Passenger2: Location: (3, 3), Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [3, 2]
# ---------------------------ROUND 6---------------------------------
# taxi_0 obs:
#  [ 0 10  0 10  3  3  3  9  1  4  3  2  1  5  2  5] , action: 0
# taxi_1 obs:
#  [ 3  3  0 10  3  3  3  9  1  4  3  2  1  5  2  5] , action: 4
# joint Message: [(1, 4), (2, 4)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,3), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 9)
# Passenger2: Location: Taxi2, Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [3, 4]
# ---------------------------ROUND 7---------------------------------
# taxi_0 obs:
#  [ 1 10  0 10  3  3  3  9  1  4  3  4  1  4  2  4] , action: 0
# taxi_1 obs:
#  [ 3  3  0 10  3  3  3  9  1  4  3  4  1  4  2  4] , action: 1
# joint Message: [(1, 3), (2, 3)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,3), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 9)
# Passenger2: Location: Taxi2, Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [3, 4]
# ---------------------------ROUND 8---------------------------------
# taxi_0 obs:
#  [ 2 10  0 10  3  3  3  9  1  4  3  4  1  3  2  3] , action: 3
# taxi_1 obs:
#  [ 2  3  0 10  3  3  3  9  1  4  3  4  1  3  2  3] , action: 1
# joint Message: [(1, 2), (2, 2)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,3), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 9)
# Passenger2: Location: Taxi2, Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [3, 4]
# ---------------------------ROUND 9---------------------------------
# taxi_0 obs:
#  [ 2  9  0 10  3  3  3  9  1  4  3  4  1  2  2  2] , action: 0
# taxi_1 obs:
#  [ 1  3  0 10  3  3  3  9  1  4  3  4  1  2  2  2] , action: 2
# joint Message: [(1, 1), (2, 1)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : :D: | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : :D: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,4), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 9)
# Passenger2: Location: Taxi2, Destination: (1, 4)
# Done: False, {'taxi_0': False, 'taxi_1': False, '__all__': False}
# Passengers Status's: [3, 4]
# ---------------------------ROUND 10---------------------------------
# taxi_0 obs:
#  [ 3  9  0 10  3  3  3  9  1  4  3  4  1  1  2  1] , action: 5
# taxi_1 obs:
#  [ 1  4  0 10  3  3  3  9  1  4  3  4  1  1  2  1] , action: 6
# joint Message: [(1, 0), (2, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : :_: | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : :_: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,4), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 9)
# Passenger2: Location: Arrived!, Destination: (1, 4)
# Done: True, {'taxi_0': True, 'taxi_1': True, '__all__': True}
# Passengers Status's: [1, 1]
# Thats all - part 1

# %% [markdown]
# In the above example, we can see that both agents intended to go to the same location to pick up the same passenger. The first agent to arrive at the passenger's location got to pick him up, while the other wasted effort and received nothing in return.

# %% [markdown]
# ## Creating the Communication Infrastructer
#
# In our solution we modeld the world as a POMDP usign the tuple $\langle S, s_{0}, A, P, R, \gamma, \Omega, O \rangle$ where
#
# - $S$ is the set of all possible environment configurations,
# - $s_{0}$ the initial state,
# - $A$ the action space, is the list of actions the taxi agents can execute within the environment **including communication**,
# - $P$ is a state transition probability function,
# - $R$ is the reward function,
# - $\gamma \in [0,1]$ is a discount factor,
# - $\Omega$ is a set of observations where the **information form the observations also becomes an observation**, and
# - $O$ is an observation function
#
#
# ## MAC-COM - simple to use:
#
# <img src='images/MAC-com.jpg' width="800" height="800">
#
#
# ##### All you need for using com module:
#     - Implement Agent_com class (inherit from Agent_com)
#         for this agent:
#         1 - make sure to implement set_data_func -  decides what data to transmit whenever it called
#         2 - recieve_func - implement yours to decide what to do with a recieved data
#             (defualt is the union_func that add the message data to the observation)
#      - implement COM module (network) - and use COM-controller
#         3 - defualt is all recieve the last messages as Joint_Message
# <img src='images/MAC_COM_pic.jpg' width="500" height="500">

# %%
environment = build_multi_env(env)
#
print('EnvironmentWrapper created')

"""
in order to use com module: 
    - implement Agent_com class (inherit from Agent_com
    - make sure to implement set_data_func - that decides what is the data that the agent will transmit whenever it called
    - u can implement your recieve_func - that decides what to do with a recieved data
        defualt is the union_func that add the message data to the observation 
"""

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = True):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None

    def set_data_func(self, obs):
        data = (self.last_action)
        return data

    # todo - implement your recive_func (defualt is union with obs)
    # def set_recive_func(self, obs, message):
    #     pass

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action

# after having our com-agent class we can set our env agents into a dicentralized_agents dict with a Random DM
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(RandomDecisionMaker(env.action_space) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}


"""
Simple use of communication network - 
    - build one using COM_net() - defualt architecture is - all masseges sent to all other agents
            *U can use more options - see at COM_net() class doc.
"""
com = COM_net()
""" 
    - initailze our new controller (DecentralizedComController) - using our env, our agents and our com module
        - this controller will perform all joint action and message delieveries at any time-step
"""
controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
controller.run(render=True, max_iteration=3)
# Out:
# EnvironmentWrapper created
# ---------------------------ROUND 1---------------------------------
# taxi_0 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 4
# taxi_1 obs:
#  MultiDiscrete([ 7 12  7 12  7 12  7 12  7 12  5  5]) , action: 1
# joint Message: [4, 1]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : :_: | : | : | : |
# | : : : : : : : : : : : |
# | : : : : : | : : :_: : |
# | : : : : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,4), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 9)
# Passenger2: Location: Arrived!, Destination: (1, 4)
# Done: True, {'taxi_0': True, 'taxi_1': True, '__all__': True}
# Passengers Status's: [1, 1]

# %% [markdown]
# ## Types of Communication
#
# When it comes to communication, we may split it into two categories:
#
# - **Explicit communication** – A direct, deliberate form of communication, where there is a clear associated intent for the transmitted information to be received by another agent or system over an established channel.
#
# <img src='https://zanzidigital.co.uk/wp-content/uploads/2017/11/chatbot-image.jpg' width=700/>
#
#
# - **Implicit communication** – Information is inferred, meaning This form of communication involves an action (or practical behaviour) representing as a message in itself, rather than a message being conveyed through language or codified gestures (such as a thumbs-up or a head nod).
# <img src='https://www.robocup.org/system/leagues/images/000/000/001/list/soccer.png?1461148054' width=800/>
#
# In the multiTaxi scenario, for example, implicit communication might take the form of the initial route each taxi takes (assuming that all agents are aware of each other's movements), but explicit communication can take the form of each taxi stating which passenger they want to pick up. There are other more explicit and implicit communication methods that might be used.
#
# The agents in the last example employ **explicit communication** to relay a message to the other agents. They specify which passenger they are going to in the message. We have completed the first three steps of the communication cycle, which means that the agents still do not know how to use communication to their benefit, nor do they know when to communicate.
#
# In the following example - we use a simple rule-based (grounded communication rule) in order to 'wisely-use' other taxis messages: if someones has a shortest path to handle your target passenger, switch to other passenger.

# %%
"""
part 2 - 
com_emerge_use of message for getting better + introducing com-module
"""
from src.decision_makers.planners.MA_com_planner import Astar_message_DM



"""
Builds Multi_taxi env
"""
m = MAP
env = MultiTaxiEnv(num_taxis=3, num_passengers=5, domain_map=m, observation_type='symbolic',rewards_table=TAXI_pickup_dropoff_REWARDS ,option_to_stand_by=True)
obs = env.reset()

environment = build_multi_env(env)
#
print('EnvironmentWrapper created')

# making agent class that communicates and heads towards 1 passenger (pickup->dropoff)
"""
in order to use com module: 
    - implement Agent_com class (inherit from Agent_com
    - make sure to implement set_data_func - that decides what is the data that the agent will transmit whenever it called
    - u can implement your recieve_func - that decides what to do with a recieved data
        defualt is the union_func that add the message data to the observation 
"""

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker : Astar_message_DM , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = False):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None
        self.last_message = None

    def set_data_func(self, obs):
        data = (self.decision_maker.taking_passenger,len(self.decision_maker.active_plan))
        return data

    # implement our recive_func
    def set_recive_func(self, obs, message):
        self.last_message = message
        self.decision_maker.save_last_message(message)
        # self.decision_maker.updateplan_message(message)

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action
#
#


# after having our com-Astar-agents class we can set our env agents into a dicentralized_agents dict
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(Astar_message_DM(env ,single_plan=True, Taxi_index=int(agent_name[-1]), domain_map=m) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}


"""
Simple use of communication network - 
    - build one using COM_net() - defualt architecture is - all masseges sent to all other agents
            *U can use more options - see at COM_net() class doc.
"""
com = COM_net()
""" 
    - initailze our new controller (DecentralizedComController) - using our env, our agents and our com module
        - this controller will perform all joint action and message delieveries at any time-step
"""
controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
#communicate first
controller.send_recieve()

#run (communication inside after each time_click)
controller.run(render=True, max_iteration=20,reset=True)
print("Thats all - part 2")
# Out:
# EnvironmentWrapper created
# send_recieve - Joint message: [(None, 0), (None, 0), (None, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : :P: : : :P: :D:_: : |
# | : : : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | |_:G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,9), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: (2, 6), Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: (2, 2), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 1---------------------------------
# Yellow Taxi_0 (re)planning results:
#   # taking Cyan passenger, len. of plan: 13 -> active:['(1,)', '(1,)', '(1,)', '(1,)', '(2,)', '(4,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(9,)']
#   # all plans:[('Yellow', 19), ('Red', 16), ('White', 17), ('Green', 22), ('Cyan', 13)]
# Red Taxi_1 (re)planning results:
#   # taking Red passenger, len. of plan: 12 -> active:['(1,)', '(1,)', '(1,)', '(2,)', '(2,)', '(4,)', '(3,)', '(3,)', '(3,)', '(0,)', '(0,)', '(6,)']
#   # all plans:[('Yellow', 15), ('Red', 12), ('White', 13), ('Green', 18), ('Cyan', 13)]
# White Taxi_2 (re)planning results:
#   # taking Red passenger, len. of plan: 10 -> active:['(3,)', '(3,)', '(3,)', '(4,)', '(3,)', '(3,)', '(3,)', '(0,)', '(0,)', '(6,)']
#   # all plans:[('Yellow', 13), ('Red', 10), ('White', 13), ('Green', 12), ('Cyan', 15)]
# taxi_0 obs:
#  [ 6  1  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 1
# taxi_1 obs:
#  [ 5  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 1
# taxi_2 obs:
#  [ 2  9  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(5, 12), (2, 11), (2, 9)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : :P: : : :P: :D: : : |
# | : : : : : | : : : :P: |
# | : : :D:_: | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: (2, 6), Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: (2, 2), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 2---------------------------------
# changing plan acording to message
# Red Taxi_1 (re)planning results:
#   # taking Cyan passenger, len. of plan: 12 -> active:['(1,)', '(1,)', '(3,)', '(3,)', '(4,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(9,)']
#   # all plans:[('Yellow', 16), ('White', 14), ('Green', 19), ('Cyan', 12)]
# taxi_0 obs:
#  [ 5  1  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 1
# taxi_1 obs:
#  [ 4  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 1
# taxi_2 obs:
#  [ 2  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(5, 11), (5, 11), (2, 8)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : :P: : : :P:_:D: : : |
# | : : : :_: | : : : :P: |
# | :_: :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,7), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: (2, 6), Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: (2, 2), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 3---------------------------------
# taxi_0 obs:
#  [ 4  1  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 1
# taxi_1 obs:
#  [ 3  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 1
# taxi_2 obs:
#  [ 2  7  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 3
# joint Message: [(5, 10), (5, 10), (2, 7)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : :P: :_: :P: :D: : : |
# | :_: : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: (2, 6), Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: (2, 2), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 4---------------------------------
# taxi_0 obs:
#  [ 3  1  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 1
# taxi_1 obs:
#  [ 2  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 3
# taxi_2 obs:
#  [ 2  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  2
#   2  2  2] , action: 4
# joint Message: [(5, 9), (5, 9), (2, 6)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | :_:P:_: : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Taxi3, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: (2, 2), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 5, 2, 2, 2]
# ---------------------------ROUND 5---------------------------------
# taxi_0 obs:
#  [ 2  1  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 2  3  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  2] , action: 3
# taxi_2 obs:
#  [ 2  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  2] , action: 3
# joint Message: [(5, 8), (5, 8), (2, 5)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : :P: : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,2), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,5), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Taxi3, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: (2, 2), Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 5, 2, 2, 2]
# ---------------------------ROUND 6---------------------------------
# taxi_0 obs:
#  [ 2  2  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  2] , action: 4
# taxi_1 obs:
#  [ 2  2  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  2] , action: 4
# taxi_2 obs:
#  [ 2  5  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  2] , action: 3
# joint Message: [(5, 7), (5, 7), (2, 4)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,2), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,4), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Taxi3, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 5, 2, 2, 4]
# ---------------------------ROUND 7---------------------------------
# taxi_0 obs:
#  [ 2  2  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_1 obs:
#  [ 2  2  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_2 obs:
#  [ 2  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 3
# joint Message: [(5, 6), (5, 6), (2, 3)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Taxi3, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 5, 2, 2, 4]
# ---------------------------ROUND 8---------------------------------
# taxi_0 obs:
#  [ 2  3  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_1 obs:
#  [ 2  3  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_2 obs:
#  [ 2  3  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 0
# joint Message: [(5, 5), (5, 5), (2, 2)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,4), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Taxi3, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 5, 2, 2, 4]
# ---------------------------ROUND 9---------------------------------
# taxi_0 obs:
#  [ 2  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_1 obs:
#  [ 2  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_2 obs:
#  [ 3  3  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 0
# joint Message: [(5, 4), (5, 4), (2, 1)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : :D: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Taxi3, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 5, 2, 2, 4]
# ---------------------------ROUND 10---------------------------------
# taxi_0 obs:
#  [ 2  5  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_1 obs:
#  [ 2  5  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 2
# taxi_2 obs:
#  [ 4  3  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  5
#   2  2  4] , action: 6
# joint Message: [(5, 3), (5, 3), (2, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : :_: : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,6), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 2, 2, 4]
# ---------------------------ROUND 11---------------------------------
# agent_2: no available plan found for passenger 4
# White Taxi_2 (re)planning results:
#   # taking White passenger, len. of plan: 15 -> active:['(2,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(4,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(7,)']
#   # all plans:[('Yellow', 17), ('White', 15), ('Green', 20)]
# taxi_0 obs:
#  [ 2  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 2
# taxi_1 obs:
#  [ 2  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 2
# taxi_2 obs:
#  [ 4  3  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 2
# joint Message: [(5, 2), (5, 2), (3, 14)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : : :_: | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,7), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,7), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,4), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 2, 2, 4]
# ---------------------------ROUND 12---------------------------------
# taxi_0 obs:
#  [ 2  7  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 2
# taxi_1 obs:
#  [ 2  7  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 2
# taxi_2 obs:
#  [ 4  4  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 2
# joint Message: [(5, 1), (5, 1), (3, 13)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :D: : : |
# | : : : : : | : : : :P: |
# | : : : : :_| : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,5), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Taxi2, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 2, 2, 4]
# ---------------------------ROUND 13---------------------------------
# taxi_0 obs:
#  [ 2  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 9
# taxi_1 obs:
#  [ 2  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 9
# taxi_2 obs:
#  [ 4  5  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  4] , action: 0
# joint Message: [(5, 0), (5, 0), (3, 12)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : :_: : : |
# | : : : : : | : : : :P: |
# | : : : : : | : : : : : |
# | :D: : :D:_: : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,5), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 2, 2, 1]
# ---------------------------ROUND 14---------------------------------
# Yellow Taxi_0 (re)planning results:
#   # taking White passenger, len. of plan: 12 -> active:['(0,)', '(0,)', '(0,)', '(4,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(7,)']
#   # all plans:[('Yellow', 14), ('White', 12), ('Green', 13)]
# Red Taxi_1 (re)planning results:
#   # taking White passenger, len. of plan: 12 -> active:['(0,)', '(0,)', '(0,)', '(4,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(7,)']
#   # all plans:[('Yellow', 14), ('White', 12), ('Green', 13)]
# taxi_0 obs:
#  [ 2  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 0
# taxi_1 obs:
#  [ 2  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 0
# taxi_2 obs:
#  [ 5  5  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 2
# joint Message: [(3, 11), (3, 11), (3, 11)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : :_: :P: |
# | : : : : : | : : : : : |
# | :D: : :D: :_: :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 2, 2, 1]
# ---------------------------ROUND 15---------------------------------
# taxi_0 obs:
#  [ 3  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 0
# taxi_1 obs:
#  [ 3  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 0
# taxi_2 obs:
#  [ 5  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 2
# joint Message: [(3, 10), (3, 10), (3, 10)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : :P: |
# | : : : : : | : :_: : : |
# | :D: : :D: : :_:P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,7), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 2, 2, 1]
# ---------------------------ROUND 16---------------------------------
# taxi_0 obs:
#  [ 4  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 0
# taxi_1 obs:
#  [ 4  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 0
# taxi_2 obs:
#  [ 5  7  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 2
# joint Message: [(3, 9), (3, 9), (3, 9)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : :P: |
# | : : : : : | : : : : : |
# | :D: : :D: : : :P: : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,8), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: (5, 8), Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 2, 2, 1]
# ---------------------------ROUND 17---------------------------------
# taxi_0 obs:
#  [ 5  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 4
# taxi_1 obs:
#  [ 5  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 4
# taxi_2 obs:
#  [ 5  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   2  2  1] , action: 4
# joint Message: [(3, 8), (3, 8), (3, 8)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : :P: |
# | : : : : : | : : : : : |
# | :D: : :D: : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,8), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: Taxi2, Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 4, 2, 1]
# ---------------------------ROUND 18---------------------------------
# taxi_0 obs:
#  [ 5  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# taxi_1 obs:
#  [ 5  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# taxi_2 obs:
#  [ 5  8  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# joint Message: [(3, 7), (3, 7), (3, 7)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : :P: |
# | : : : : : | : : : : : |
# | :D: : :D: : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,7), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,7), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,7), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: Taxi2, Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 4, 2, 1]
# ---------------------------ROUND 19---------------------------------
# taxi_0 obs:
#  [ 5  7  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# taxi_1 obs:
#  [ 5  7  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# taxi_2 obs:
#  [ 5  7  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# joint Message: [(3, 6), (3, 6), (3, 6)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : :P: |
# | : : : : : | : : : : : |
# | :D: : :D: : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,6), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: Taxi2, Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 4, 2, 1]
# ---------------------------ROUND 20---------------------------------
# taxi_0 obs:
#  [ 5  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# taxi_1 obs:
#  [ 5  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# taxi_2 obs:
#  [ 5  6  5 11  2  6  5  8  3 10  2  2  1  9  4  3  5  1  5  4  2  8  2  1
#   4  2  1] , action: 3
# joint Message: [(3, 5), (3, 5), (3, 5)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : :P: |
# | : : : : : | : : : : : |
# | :D: : :D: : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,5), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: Taxi2, Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 4, 2, 1]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : | : : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : :P: |
# | : : : : : | : : : : : |
# | :D: : :D: : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,5), Collided: False
# Passenger1: Location: (5, 11), Destination: (1, 9)
# Passenger2: Location: Arrived!, Destination: (4, 3)
# Passenger3: Location: Taxi2, Destination: (5, 1)
# Passenger4: Location: (3, 10), Destination: (5, 4)
# Passenger5: Location: Arrived!, Destination: (2, 8)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 4, 2, 1]
# Thats all - part 2

# %% [markdown]
# ## Using Communication to Our Advantage
#
# Having established that the agents can send and receive messages, they must now learn how to utilize them and what to do with them. They are pointless if they do not behave in line with the massages. In emergent communication we can learn how to do it autonomously

# %%
"""
part 2.2 - 
agents learn now - hierarchical_tasks
"""

# import hierarchical_tasks multi taxi env
from src.environments.hirarchical_Wrapper import Multi_Taxi_Task_Wrapper
from src.decision_makers.planners.Com_High_level_Planner import Astar_message_highlevel_DM
"""
Builds Multi_taxi env
"""
m = MAP
env = MultiTaxiEnv(num_taxis=3, num_passengers=5, domain_map=m, observation_type='symbolic',rewards_table=TAXI_pickup_dropoff_REWARDS ,option_to_stand_by=True)

obs = env.reset()

environment = build_multi_env(env)

environment =  Multi_Taxi_Task_Wrapper(environment)
#
print('EnvironmentWrapper Multi_Taxi_Task_Wrapper created')

# making agent class that communicates and heads towards 1 passenger (pickup->dropoff)

class Heading_message_agent(Agent_Com):

    def __init__(self, decision_maker : Astar_message_highlevel_DM , sensor_function =None, message_filter = None, AgentName = None, bandW = math.inf, union_recieve = False):
        super().__init__(decision_maker , sensor_function, message_filter, AgentName, bandW, union_recieve)
        self.last_action = None
        self.last_message = None

    def set_data_func(self, obs):
        data = (self.decision_maker.taking_passenger,len(self.decision_maker.active_plan))
        return data

    # implement our recive_func
    def set_recive_func(self, obs, message):
        self.last_message = message
        self.decision_maker.save_last_message(message)
        # self.decision_maker.updateplan_message(message)

    # saves last action of the agent - not necessary for com module
    def set_last_action(self, action):
        self.last_action = action


# run again - high-level
env_agents = environment.get_env_agents()
decentralized_agents = {agent_name: Heading_message_agent(Astar_message_highlevel_DM(env ,single_plan=True, Taxi_index=int(agent_name[-1]), domain_map=m) ,AgentName=agent_name)             # Agent(LearningDecisionMaker(env.action_space))  # can use diffrent DM
                        for agent_name in env_agents}

controller = DecentralizedComController(environment, decentralized_agents, com)
"""
activate 
"""
#communicate first
controller.send_recieve()

#run (communication inside after each time_click)
controller.run(render=True, max_iteration=250,reset=True)

# SHOW REWARDS
reward = controller.total_rewards
totals = {}
for r in reward[0]:
    totals[r] = 0
total=0
for r in reward:
    for key, value in r.items():
        totals[key]+=value
        total+=value
print(f"----------------------------------\n total reward of all agents: {total}, {totals} \n----------------------------------")
print("Thats all - part 2.2")
# Out:
# EnvironmentWrapper Multi_Taxi_Task_Wrapper created
# send_recieve - Joint message: [(None, 0), (None, 0), (None, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : :_: : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : : : : : : : : : :P|
# | | :G|P| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (6,6), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,4), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: (6, 3), Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 1---------------------------------
# Yellow Taxi_0 (re)planning results:
#   # taking Red passenger, len. of plan: 14 -> active:['(2,)', '(0,)', '(0,)', '(0,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(1,)', '(6,)']
#   # all plans:[('Yellow', 26), ('Red', 14), ('White', 16), ('Green', 20), ('Cyan', 21)]
# Red Taxi_1 (re)planning results:
#   # taking Red passenger, len. of plan: 12 -> active:['(3,)', '(1,)', '(3,)', '(3,)', '(0,)', '(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(1,)', '(6,)']
#   # all plans:[('Yellow', 18), ('Red', 12), ('White', 16), ('Green', 12), ('Cyan', 17)]
# White Taxi_2 (re)planning results:
#   # taking Red passenger, len. of plan: 12 -> active:['(3,)', '(0,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(1,)', '(6,)']
#   # all plans:[('Yellow', 22), ('Red', 12), ('White', 16), ('Green', 16), ('Cyan', 17)]
# taxi_0 obs:
#  [ 0  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# taxi_1 obs:
#  [ 6  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  4  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# joint Message: [(2, 13), (2, 11), (2, 11)]
# +-----------------------+
# | : |F:_| : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : :_: : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : : : : : : : : : :P|
# | | :G|P| |_:G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (6,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: (6, 3), Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 2---------------------------------
# changing plan acording to message
# Yellow Taxi_0 (re)planning results:
#   # taking White passenger, len. of plan: 17 -> active:['(3,)', '(0,)', '(0,)', '(3,)', '(3,)', '(0,)', '(0,)', '(0,)', '(4,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(1,)', '(7,)']
#   # all plans:[('Yellow', 25), ('White', 17), ('Green', 19), ('Cyan', 20)]
# taxi_0 obs:
#  [ 0  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 6  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 2  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# joint Message: [(3, 16), (2, 10), (2, 10)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : : : : : : : : : |
# | : : :_: : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : : : :_: : : : : :P|
# | | :G|P| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: (6, 3), Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 3---------------------------------
# taxi_0 obs:
#  [ 0  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 3  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# joint Message: [(3, 15), (2, 9), (2, 9)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D:_: : |D: : : : : |
# |P: : : :_: : : : : : :P|
# | | :G|P| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: (6, 3), Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 4---------------------------------
# taxi_0 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 5  4  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 4  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# joint Message: [(3, 14), (2, 8), (2, 8)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : :_: : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : :_: : : : : : : :P|
# | | :G|P| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: (6, 3), Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 5---------------------------------
# taxi_0 obs:
#  [ 2  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 5  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 5  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# joint Message: [(3, 13), (2, 7), (2, 7)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | :_: : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : : : : : : : : : :P|
# | | :G|P| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (6,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: (6, 3), Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 2, 2, 2, 2]
# ---------------------------ROUND 6---------------------------------
# taxi_0 obs:
#  [ 2  1  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  2
#   2  2  2] , action: 2
# joint Message: [(3, 12), (2, 6), (2, 6)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# |_: : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : : : : : : : : : :P|
# | | :G| | | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (6,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Taxi2, Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 4, 2, 2, 2]
# ---------------------------ROUND 7---------------------------------
# taxi_0 obs:
#  [ 2  0  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# joint Message: [(3, 11), (2, 5), (2, 5)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : : : : : : : : : |
# |_: : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Taxi2, Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 4, 2, 2, 2]
# ---------------------------ROUND 8---------------------------------
# taxi_0 obs:
#  [ 3  0  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 5  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# joint Message: [(3, 10), (2, 4), (2, 4)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# |_: :D: : : |D: : : : : |
# |P: : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Taxi2, Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 4, 2, 2, 2]
# ---------------------------ROUND 9---------------------------------
# taxi_0 obs:
#  [ 4  0  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 4  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# joint Message: [(3, 9), (2, 3), (2, 3)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# |P: : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Taxi2, Destination: (1, 3)
# Passenger3: Location: (5, 0), Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 4, 2, 2, 2]
# ---------------------------ROUND 10---------------------------------
# taxi_0 obs:
#  [ 5  0  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 3
# taxi_1 obs:
#  [ 3  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   2  2  2] , action: 2
# joint Message: [(3, 8), (2, 2), (2, 2)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,0), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Taxi2, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 4, 3, 2, 2]
# ---------------------------ROUND 11---------------------------------
# taxi_0 obs:
#  [ 5  0  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 2  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   3  2  2] , action: 2
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   3  2  2] , action: 2
# joint Message: [(3, 7), (2, 1), (2, 1)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:D: : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,1), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Taxi2, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 4, 3, 2, 2]
# ---------------------------ROUND 12---------------------------------
# taxi_0 obs:
#  [ 5  1  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 1  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   3  2  2] , action: 2
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  4
#   3  2  2] , action: 2
# joint Message: [(3, 6), (2, 0), (2, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D:_: : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,2), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,3), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 3, 2, 2]
# ---------------------------ROUND 13---------------------------------
# Red Taxi_1 (re)planning results:
#   # taking White passenger, len. of plan: 7 -> active:['(2,)', '(2,)', '(0,)', '(2,)', '(0,)', '(0,)', '(7,)']
#   # all plans:[('Yellow', 24), ('White', 7), ('Green', 18), ('Cyan', 19)]
# changing plan acording to message
# Red Taxi_1 (re)planning results:
#   # taking Green passenger, len. of plan: 18 -> active:['(2,)', '(2,)', '(0,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(1,)', '(8,)']
#   # all plans:[('Yellow', 24), ('Green', 18), ('Cyan', 19)]
# White Taxi_2 (re)planning results:
#   # taking White passenger, len. of plan: 6 -> active:['(1,)', '(2,)', '(2,)', '(2,)', '(1,)', '(7,)']
#   # all plans:[('Yellow', 21), ('White', 6), ('Green', 15), ('Cyan', 20)]
# taxi_0 obs:
#  [ 5  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 1  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 4
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# joint Message: [(3, 5), (4, 17), (3, 5)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: :_: | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,3), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,4), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 3, 2, 2]
# ---------------------------ROUND 14---------------------------------
# taxi_0 obs:
#  [ 5  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 1  4  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 4
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# joint Message: [(3, 4), (4, 16), (3, 4)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : :_| : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,4), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 3, 2, 2]
# ---------------------------ROUND 15---------------------------------
# taxi_0 obs:
#  [ 5  4  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 1  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 4
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# joint Message: [(3, 3), (4, 15), (3, 3)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : :_: : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,5), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 3, 2, 2]
# ---------------------------ROUND 16---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 2  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 4
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# joint Message: [(3, 2), (4, 14), (3, 2)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : :_: : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,6), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 3, 2, 2]
# ---------------------------ROUND 17---------------------------------
# taxi_0 obs:
#  [ 5  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 2  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 4
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# joint Message: [(3, 1), (4, 13), (3, 1)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : :_: : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |D: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,7), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Taxi1, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 3, 2, 2]
# ---------------------------ROUND 18---------------------------------
# taxi_0 obs:
#  [ 4  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# taxi_1 obs:
#  [ 2  7  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 4
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   3  2  2] , action: 3
# joint Message: [(3, 0), (4, 12), (3, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : :_: : : |
# | : : : : : | : : :P: : |
# | : :D: : : |_: : : : : |
# | : : : : : : : : : : :P|
# | | :G|_| | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,6), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,8), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (6,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 2, 2]
# ---------------------------ROUND 19---------------------------------
# Yellow Taxi_0 (re)planning results:
#   # taking Green passenger, len. of plan: 12 -> active:['(2,)', '(2,)', '(2,)', '(0,)', '(0,)', '(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(1,)', '(8,)']
#   # all plans:[('Yellow', 18), ('Green', 12), ('Cyan', 15)]
# White Taxi_2 (re)planning results:
#   # taking Green passenger, len. of plan: 15 -> active:['(1,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(2,)', '(0,)', '(4,)', '(1,)', '(1,)', '(1,)', '(1,)', '(1,)', '(8,)']
#   # all plans:[('Yellow', 21), ('Green', 15), ('Cyan', 20)]
# changing plan acording to message
# White Taxi_2 (re)planning results:
#   # taking Cyan passenger, len. of plan: 20 -> active:['(1,)', '(2,)', '(2,)', '(2,)', '(1,)', '(1,)', '(2,)', '(2,)', '(2,)', '(4,)', '(1,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(9,)']
#   # all plans:[('Yellow', 21), ('Cyan', 20)]
# taxi_0 obs:
#  [ 4  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_1 obs:
#  [ 2  8  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_2 obs:
#  [ 6  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 5
# joint Message: [(4, 11), (4, 11), (5, 19)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : :_: : |
# | : : : : : | : : :P: : |
# | : :D: : : | :_: : : : |
# | : : :_: : : : : : : :P|
# | | :G| | | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,7), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,3), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 2, 2]
# ---------------------------ROUND 20---------------------------------
# taxi_0 obs:
#  [ 4  7  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_2 obs:
#  [ 5  3  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 5
# joint Message: [(4, 10), (4, 10), (5, 18)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : | : :_: : : |
# | : : : :_: : : : : : :P|
# | | :G| | | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,4), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 2, 2]
# ---------------------------ROUND 21---------------------------------
# taxi_0 obs:
#  [ 4  8  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_1 obs:
#  [ 3  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_2 obs:
#  [ 5  4  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 5
# joint Message: [(4, 9), (4, 9), (5, 17)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : | : : :_: : |
# | : : : : :_: : : : : :P|
# | | :G| | | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (4,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,5), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 2, 2]
# ---------------------------ROUND 22---------------------------------
# taxi_0 obs:
#  [ 4  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_1 obs:
#  [ 4  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_2 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 5
# joint Message: [(4, 8), (4, 8), (5, 16)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : | : : : : : |
# | : : : : : :_: : :_: :P|
# | | :G| | | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (5,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 2, 2]
# ---------------------------ROUND 23---------------------------------
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_1 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_2 obs:
#  [ 5  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 5
# joint Message: [(4, 7), (4, 7), (5, 15)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : |_: : : : : |
# | : : : : : : : : : : :P|
# | | :G| | | :G| | |P: | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (6,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (4,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: (6, 9), Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 2, 2]
# ---------------------------ROUND 24---------------------------------
# taxi_0 obs:
#  [ 6  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_1 obs:
#  [ 6  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 4
# taxi_2 obs:
#  [ 4  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  2  2] , action: 5
# joint Message: [(4, 6), (4, 6), (5, 14)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : |_: : :P: : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (6,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (6,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Taxi2, Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 4, 2]
# ---------------------------ROUND 25---------------------------------
# taxi_0 obs:
#  [ 6  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_1 obs:
#  [ 6  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_2 obs:
#  [ 3  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 5
# joint Message: [(4, 5), (4, 5), (5, 13)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | :_: :P: : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (5,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,7), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Taxi2, Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 4, 2]
# ---------------------------ROUND 26---------------------------------
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_1 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_2 obs:
#  [ 3  7  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 5
# joint Message: [(4, 4), (4, 4), (5, 12)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : :_:P: : |
# | : :D: : : | : : : : : |
# | : : : : : : : : :_: :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (4,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,8), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Taxi2, Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 4, 2]
# ---------------------------ROUND 27---------------------------------
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_1 obs:
#  [ 4  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_2 obs:
#  [ 3  8  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 5
# joint Message: [(4, 3), (4, 3), (5, 11)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : :P: : |
# | : :D: : : | : : : : : |
# | : : : : : : : : :_: :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (3,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,9), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Taxi2, Destination: (1, 9)
# Passenger5: Location: (3, 9), Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 4, 2]
# ---------------------------ROUND 28---------------------------------
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_1 obs:
#  [ 3  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 4
# taxi_2 obs:
#  [ 3  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  2] , action: 5
# joint Message: [(4, 2), (4, 2), (5, 10)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : :_: :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (3,9), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Taxi2, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 4, 5]
# ---------------------------ROUND 29---------------------------------
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  5] , action: 4
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  5] , action: 4
# taxi_2 obs:
#  [ 3  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  5] , action: 5
# joint Message: [(4, 1), (4, 1), (5, 9)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :D| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : :_: :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,9), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Taxi2, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 4, 5]
# ---------------------------ROUND 30---------------------------------
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  5] , action: 4
# taxi_1 obs:
#  [ 1  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  5] , action: 4
# taxi_2 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  4  5] , action: 5
# joint Message: [(4, 0), (4, 0), (5, 8)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | :_| : |
# | : : : : : : : : : : : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : :_: :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (1,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,8), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 1, 5]
# ---------------------------ROUND 31---------------------------------
# agent_0: no available plan found for passenger 4
# Yellow Taxi_0 (re)planning results:
#   # taking Yellow passenger, len. of plan: 14 -> active:['(2,)', '(2,)', '(4,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(5,)']
#   # all plans:[('Yellow', 14)]
# agent_1: no available plan found for passenger 4
# Red Taxi_1 (re)planning results:
#   # taking Yellow passenger, len. of plan: 18 -> active:['(0,)', '(2,)', '(2,)', '(0,)', '(0,)', '(0,)', '(4,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(3,)', '(1,)', '(3,)', '(3,)', '(3,)', '(5,)']
#   # all plans:[('Yellow', 18)]
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 1
# taxi_1 obs:
#  [ 1  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 1
# taxi_2 obs:
#  [ 2  8  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 5
# joint Message: [(1, 13), (1, 17), (5, 7)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : :_:P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,7), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 1, 5]
# ---------------------------ROUND 32---------------------------------
# changing plan acording to message
# agent_1: no available plan found for passenger 4
# agent_1: no available plan was found (for all)
# agent_1: no action available - using defualt
# taxi_0 obs:
#  [ 5 10  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 1
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 0
# taxi_2 obs:
#  [ 2  7  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 5
# joint Message: [(1, 12), (0, 0), (5, 6)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : :P|
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,11), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,6), Collided: False
# Passenger1: Location: (5, 11), Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [2, 1, 1, 1, 5]
# ---------------------------ROUND 33---------------------------------
# taxi_0 obs:
#  [ 5 11  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 1
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 0
# taxi_2 obs:
#  [ 2  6  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  2  1
#   1  1  5] , action: 5
# joint Message: [(1, 11), (0, 0), (5, 5)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,11), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (2,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 5]
# ---------------------------ROUND 34---------------------------------
# taxi_0 obs:
#  [ 5 11  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 1
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 0
# taxi_2 obs:
#  [ 2  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 5
# joint Message: [(1, 10), (0, 0), (5, 4)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,10), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,5), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 5]
# ---------------------------ROUND 35---------------------------------
# taxi_0 obs:
#  [ 5 10  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 1
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 0
# taxi_2 obs:
#  [ 1  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 5
# joint Message: [(1, 9), (0, 0), (5, 3)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,9), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,4), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Taxi3, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 5]
# ---------------------------ROUND 36---------------------------------
# taxi_0 obs:
#  [ 5  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 1
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 0
# taxi_2 obs:
#  [ 1  4  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  5] , action: 5
# joint Message: [(1, 8), (0, 0), (5, 2)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |D: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,8), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,3), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# ...
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 239---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 240---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 241---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 242---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 243---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 244---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 245---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 246---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 247---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 248---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 249---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ---------------------------ROUND 250---------------------------------
# taxi_0 obs:
#  [ 5  5  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_1 obs:
#  [ 2  9  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# taxi_2 obs:
#  [ 1  2  5 11  6  3  5  0  6  9  3  9  4  2  1  3  4  6  1  9  1  2  3  1
#   1  1  1] , action: 0
# joint Message: [(0, 0), (0, 0), (0, 0)]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# +-----------------------+
# | : |F: | : | : | : |F: |
# | : |_: : : | : | : | : |
# | : : : : : : : : :_: : |
# | : : : : : | : : : : : |
# | : :D: : : | : : : : : |
# | : : : : : : : : : : : |
# | | :G| | | :G| | | : | |
# +-----------------------+
# Taxi0-YELLOW: Fuel: inf, Location: (5,5), Collided: False
# Taxi1-RED: Fuel: inf, Location: (2,9), Collided: False
# Taxi2-WHITE: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (4, 2)
# Passenger2: Location: Arrived!, Destination: (1, 3)
# Passenger3: Location: Arrived!, Destination: (4, 6)
# Passenger4: Location: Arrived!, Destination: (1, 9)
# Passenger5: Location: Arrived!, Destination: (1, 2)
# Done: False, {'taxi_0': False, 'taxi_1': False, 'taxi_2': False, '__all__': False}
# Passengers Status's: [3, 1, 1, 1, 1]
# ----------------------------------
#  total reward of all agents: 547, {'taxi_0': 164, 'taxi_1': 273, 'taxi_2': 110}
# ----------------------------------
# Thats all - part 2.2

# %% [markdown]
# We can see a major performence improvement - this method can easily solve a wide, Multi-Agent domain, using low-bandwidth com.
#
# After we thought about the solution of the 5th and final step ('Interpretation') by ourself, We can design a RL Agent that can learn how to interpret and act by it own.
# #### PPO RL agent learn how to act in the high-level action space (X - handling passenger x, 0 - stby)
#
# we show how high-level single agent can learn how to act.
# further research - learning what to communicate (cooperative/adverserial), and learning how to interpret-act acorrding to other agents 'signals'

# %%
"""
part 3 - 
agents learn now - high level PPO, low-level a-star
"""

from src.decision_makers.High_level_learner import LearningHighLevelDecisionMaker

env = MultiTaxiEnv(num_taxis=1, num_passengers=2, domain_map=MAP2, observation_type='symbolic', option_to_stand_by=True)
env.agents = env.taxis_names
env = EnvWrappper(env, env.agents)
env = Multi_Taxi_Task_Wrapper(env)
obs = env.reset()

D_M = LearningHighLevelDecisionMaker(env.action_space)
obs = env.reset()
env.env.env.render()
for i in range(50):
    print(f"obs:{type(obs)}")
    a = D_M.get_action(obs)
    print(f"next action: {env.index_action_dictionary[a]}")
    obs, r, done, info = env.step(a)
    env.env.env.render()
    if done: break
print("that all - part 3")
# Out:
# +-------+
# |_:P|P: |
# | : | : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,0), Collided: False
# Passenger1: Location: (0, 2), Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|P: |
# | : | : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Passenger1: Location: (0, 2), Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|P: |
# | :_| : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,1), Collided: False
# Passenger1: Location: (0, 2), Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|P: |
# | : | : |
# | :_: :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Passenger1: Location: (0, 2), Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|P: |
# | : | : |
# | : :_:D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: (0, 2), Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|P: |
# | : |_: |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: (0, 2), Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|P: |
# | : | : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,2), Collided: False
# Passenger1: Location: (0, 2), Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [2, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|F: |
# | : | : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [3, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|F: |
# | : | : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [3, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|F: |
# | : | : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [3, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|F: |
# | : | : |
# | : : :D|
# | | :D| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,2), Collided: False
# Passenger1: Location: Taxi1, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [3, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 1
# +-------+
# | :P|F: |
# | : | : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (3,2), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | :P|F: |
# | : | : |
# | : :_:D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | :P|F: |
# | : | : |
# | :_: :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | :P|F: |
# | :_| : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | :P|F: |
# | : | : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: (0, 1), Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 2]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |F: |
# | : | : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (0,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: Taxi1, Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |F: |
# | : | : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (1,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: Taxi1, Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |F: |
# | : | : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,1), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: Taxi1, Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |F: |
# | : | : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,2), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: Taxi1, Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |F: |
# | : | : |
# | : : :D|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,3), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: Taxi1, Destination: (2, 3)
# Done: False, {'taxi_0': False, '__all__': False}
# Passengers Status's: [1, 3]
# obs:<class 'numpy.ndarray'>
# next action: handling pass 2
# +-------+
# | : |F: |
# | : | : |
# | : : :_|
# | | :G| |
# +-------+
# Taxi0-YELLOW: Fuel: inf, Location: (2,3), Collided: False
# Passenger1: Location: Arrived!, Destination: (3, 2)
# Passenger2: Location: Arrived!, Destination: (2, 3)
# Done: True, {'taxi_0': True, '__all__': True}
# Passengers Status's: [1, 1]
# that all - part 3

# %% [markdown]
# ## Compilling Communication for RL as an Action + Com-Reward
#
# To explain implicit communication we will look at the Speaker Lister environment. In this environment there are 2 agents in which one agent (speaker) has information about the goal and has a limmited mode of communication with the second agent (listener) must use the speaker's communications and its limitted observations to navigate a 2D space toward the goal. The speaker agent cannot navigate, and the listener object cannot communicate.
#
# We used this setting to implement our emergent communication in the form of deciding when to 'communicate' - SPEAKER will allways 'point' on the right target, Listener should learn when to use the action to observe the Speaker's pointer (or in other wards, Listener learns when to ask for help).

# %% [markdown]
# #### speaker-listener com as action - env-wrapper
# #### speaker - 'point-to-target' if asked, listener can ask for 'help' from speaker (action 0 - no move)
# <img src='images/seaker-point.jpg' width="500" height="500">
#
# ##### Listener new-wrapper :
# The speaker observation is of type `Box(-inf, inf, (9,), float32)`
# 1. listener agent velocity X
# 2. listener agent velocity Y
# 3. red landmark X pos - listener agent X pos
# 4. red landmark Y pos - listener agent Y pos
# 5. blue landmark X pos - listener agent X pos
# 6. blue landmark Y pos - listener agent Y pos
# 7. green landmark X pos - listener agent X pos
# 8. green landmark Y pos - listener agent Y pos
# 9. communication channel -
#     if com action was choosen last - speaker 'points' at destination (1-8 - directions shown above). else (no com from SPEAKER) - 0
# ##### Discrete ACTIONS:
# * 0 - do nothing and ask for communicate (com penalty)
# * 1 - push left (add velocity in negative x-axis direction)
# * 2 - push right (add velocity in positive x-axis direction)
# * 3 - push down (add velocity in negative y-axis direction)
# * 4 - push up (add velocity in positive t-axis direction)

# %%
import numpy as np
from gym import Wrapper
from copy import deepcopy
from pettingzoo.mpe import simple_speaker_listener_v3
from stable_baselines3 import PPO

# speaker action-to-index dict
SPEAKER_DISCRETE_ACTIONS = {

    'A': 0,
    'B': 1,
    'C': 2,
    'nothing' : 3,

}

# listener action-to-index dict
LISTENER_DISCRETE_ACTIONS = {
    'nothing': 0,
    'left':    1,
    'right':   2,
    'down':    3,
    'up':      4
}

from gym.spaces import Discrete, Box

"""#### Custom gym Wrapper
"""
class ListenerOnlyCOMWrapper(Wrapper):

    def __init__(self, env, com_allways_on = False, com_reward = -0.1):
        super().__init__(env)
        self.com_allways_on = com_allways_on
        self.com_reward = com_reward

        # reset to skip speaker before new game
        self.obs = self.reset()

        # set single agent list
        self.agents = self.agents[1:]

        self.observation_space = self.get_observation_space()

        #set action space (listener)
        self.action_space = env.action_spaces[self.agents[0]]

    def get_observation_space(self):
        return Box(low=-np.inf,high=np.inf , shape= (len(self.obs),), dtype=np.float32)

    def reset(self):
        super().reset()


        # skip speaker action
        self.__step_speaker()
        self.obs,_,_,_ = self.env.last()
        self.obs = self.fix_obs(self.obs, self.com_allways_on)
        return self.obs

    def step(self, action):
        # CHANGE ACTION AS NEEDED
        com = action == 0
        super().step(action)
        ob, _, done, _ = self.env.last()  # do listener action

        # skip speaker action - if com==True, speaker 'speaks' else - 0 speak will be performed
        self.__step_speaker()

        step_rets = self.env.last()

        if self.com_allways_on:  com = True

        self.obs = self.fix_obs(step_rets[0], com)

        reward_com = 0
        if com:
            # get - minus-reward for com use - adjust reward by initializing
            if not self.com_allways_on: reward_com = self.com_reward

        return (self.obs,step_rets[1] + reward_com, step_rets[2], step_rets[3])

    def fix_obs(self, obs, com):
        if len(obs)<5: return obs
        obs = np.array(obs[:-2])
        point = int(obs[-1])
        if not com or point==3:
            obs[-1] = 0
            return obs
        try:
            x = obs[2+point*2]
            y = obs[3+point*2]
        except:
            print('out of bounds')
        myradians = math.atan2(y, x)
        deg = int(math.degrees(myradians))
        if deg<0:
            deg+=360
        output = deg // 45
        obs[-1] = (output+1)
        return obs

    def __step_speaker(self):
        goal_color, _, done, _ = self.env.last()

        # speaker is done before the listener.
        if done:
            return

        # step with the correct action type
        if self.env.unwrapped.continuous_actions:
            super().step(goal_color)
        else:
            super().step(np.argmax(goal_color))

env = simple_speaker_listener_v3.env(max_cycles=200, continuous_actions=False)
env = ListenerOnlyCOMWrapper(env, com_allways_on=False)
print(f'custom wrapped environment: {env}')

#train PPO agent method
def train_model(env):
    env_copy = deepcopy(env)
    env_copy.reset()
    model = PPO("MlpPolicy", env_copy, verbose=1)
    for batch in range(200):
        print(f"batch: {batch}")
        model.learn(total_timesteps=8000, n_eval_episodes=40)
        env_copy.reset()
    return model

def get_ppo_agent(is_com_active):
    if is_com_active:
        model_file_name = 'S-L_PPO_base'
    else:
        model_file_name = 'S-L_PPO_com10'
    try:
        model = PPO.load(model_file_name)
    except:
        model = train_model(env)
        model.save(model_file_name)
    return model

# run (n_iter) episodes after training and render
def run(env,model,n_iter):
    for m in range(n_iter):
        observation = env.reset()
        env.render()
        for i in range(env.unwrapped.max_cycles):
            # choose an action and execute
            action = model.predict(observation)
            action = action[0]
            print(f'step {i}')
            print(f'observation: {observation}')
            observation, reward, done, info = env.step(action)

            # log everything
            c = "no_com"
            if action == 0 or env.com_allways_on: c = "com active"
            print(f'action:      {action}  com:{c}')
            print(f'reward:      {reward}')
            print()

            # if done, the episode is complete. no more actions can be taken
            if done:
                break

            env.render()
        env.close()

model = get_ppo_agent(env.com_allways_on)

run(env,model,5)

print("that all - part 4")
# Out:
# custom wrapped environment: <ListenerOnlyCOMWrappersimple_speaker_listener_v3>
# /usr/local/Caskroom/miniconda/base/envs/fstma-tut11/lib/python3.8/site-packages/pettingzoo/utils/wrappers/base.py:58: UserWarning: The `action_spaces` dictionary is deprecated. Use the `action_space` function instead.
#   warnings.warn(
# step 0
# observation: [ 0.          0.         -0.0766268  -0.58894676  0.8385942  -1.0765448
#   0.6375569   0.21733373  0.        ]
# action:      3  com:no_com
# reward:      -1.757034286562718
#
# step 1
# observation: [ 0.         -0.5        -0.0766268  -0.53894675  0.8385942  -1.0265447
#   0.6375569   0.26733375  0.        ]
# action:      3  com:no_com
# reward:      -1.5850452089940839
#
# step 2
# observation: [ 0.         -0.875      -0.0766268  -0.45144677  0.8385942  -0.9390447
#   0.6375569   0.35483375  0.        ]
# action:      3  com:no_com
# reward:      -1.381260256046246
#
# step 3
# observation: [ 0.         -1.15625    -0.0766268  -0.33582175  0.8385942  -0.82341975
#   0.6375569   0.47045875  0.        ]
# action:      3  com:no_com
# reward:      -1.1747984405093175
#
# step 4
# observation: [ 0.         -1.3671875  -0.0766268  -0.19910301  0.8385942  -0.686701
#   0.6375569   0.6071775   0.        ]
# action:      2  com:no_com
# reward:      -0.9631259322127177
#
# step 5
# observation: [ 0.5        -1.0253906  -0.1266268  -0.09656395  0.7885942  -0.58416194
#   0.5875569   0.70971656  0.        ]
# action:      2  com:no_com
# reward:      -0.748843347938436
#
# step 6
# observation: [ 0.875      -0.76904297 -0.2141268  -0.01965965  0.7010942  -0.50725764
#   0.5000569   0.78662086  0.        ]
# action:      4  com:no_com
# reward:      -0.6534006580781243
#
# step 7
# observation: [ 0.65625    -0.07678223 -0.2797518  -0.01198143  0.6354692  -0.4995794
#   0.4344319   0.79429907  0.        ]
# action:      2  com:no_com
# reward:      -0.5314234416426449
#
# step 8
# observation: [ 0.9921875  -0.05758667 -0.37897056 -0.00622276  0.5362504  -0.49382073
#   0.33521315  0.80005777  0.        ]
# action:      2  com:no_com
# reward:      -0.40922114054126085
#
# step 9
# observation: [ 1.2441406  -0.04319    -0.5033846  -0.00190376  0.4118364  -0.48950174
#   0.2107991   0.8043767   0.        ]
# action:      3  com:no_com
# reward:      -0.29178365219693625
#
# step 10
# observation: [ 0.93310547 -0.5323925  -0.5966952   0.05133549  0.31852582 -0.4362625
#   0.11748856  0.857616    0.        ]
# action:      3  com:no_com
# reward:      -0.1817201563937309
#
# step 11
# observation: [ 0.6998291  -0.8992944  -0.6666781   0.14126493  0.24854292 -0.34633306
#   0.04750565  0.9475454   0.        ]
# action:      1  com:no_com
# reward:      -0.13832080406129912
#
# step 12
# observation: [ 0.02487183 -0.6744708  -0.66916525  0.20871201  0.24605574 -0.27888596
#   0.04501846  1.0149925   0.        ]
# action:      1  com:no_com
# reward:      -0.1386691482853068
#
# step 13
# observation: [-0.48134613 -0.50585306 -0.6210306   0.2592973   0.29419035 -0.22830066
#   0.09315308  1.0655779   0.        ]
# action:      1  com:no_com
# reward:      -0.18085904338698106
#
# step 14
# observation: [-0.8610096  -0.37938982 -0.5349297   0.2972363   0.3802913  -0.19036168
#   0.17925404  1.1035168   0.        ]
# action:      0  com:com active
# reward:      -0.3241206880529568
#
# step 15
# observation: [-0.6457572  -0.28454235 -0.47035396  0.32569054  0.444867   -0.16190743
#   0.24382976  1.131971    4.        ]
# action:      2  com:no_com
# reward:      -0.21627285321008594
#
# step 16
# observation: [ 0.0156821  -0.21340677 -0.47192216  0.3470312   0.44329882 -0.14056677
#   0.24226154  1.1533117   0.        ]
# action:      2  com:no_com
# reward:      -0.16927568383009584
#
# step 17
# observation: [ 0.51176155 -0.16005507 -0.52309835  0.36303672  0.39212266 -0.12456125
#   0.19108538  1.1693172   0.        ]
# action:      2  com:no_com
# reward:      -0.10492742059808817
#
# step 18
# observation: [ 0.8838212  -0.12004131 -0.6114805   0.37504086  0.30374053 -0.11255712
#   0.10270327  1.1813214   0.        ]
# action:      1  com:no_com
# reward:      -0.093353209293064
#
# step 19
# observation: [ 0.16286589 -0.09003098 -0.627767    0.38404393  0.28745395 -0.10355403
#   0.08641668  1.1903244   0.        ]
# action:      4  com:no_com
# reward:      -0.09730725102350755
#
# step 20
# observation: [ 0.12214942  0.43247676 -0.639982    0.34079626  0.27523902 -0.1468017
#   0.07420174  1.1470767   0.        ]
# action:      0  com:com active
# reward:      -0.2029234631011362
#
# step 21
# observation: [ 0.09161206  0.32435757 -0.64914316  0.30836052  0.26607782 -0.17923746
#   0.06504054  1.1146411   4.        ]
# action:      1  com:no_com
# reward:      -0.13704731990701638
#
# step 22
# observation: [-0.43129095  0.24326818 -0.6060141   0.2840337   0.3092069  -0.20356427
#   0.10816963  1.0903141   0.        ]
# action:      2  com:no_com
# reward:      -0.13420297628496622
#
# step 23
# observation: [ 0.17653179  0.18245113 -0.62366724  0.26578858  0.2915537  -0.22180939
#   0.09051646  1.072069    0.        ]
# action:      1  com:no_com
# reward:      -0.16324703317375153
#
# step 24
# observation: [-0.36760116  0.13683835 -0.58690715  0.25210473  0.32831383 -0.23549323
#   0.12727657  1.0583853   0.        ]
# action:      3  com:no_com
# reward:      -0.16497381729098384
#
# step 25
# observation: [-0.27570087 -0.39737123 -0.5593371   0.29184186  0.35588393 -0.1957561
#   0.15484665  1.0981224   0.        ]
# action:      1  com:no_com
# reward:      -0.20949518687964205
#
# step 26
# observation: [-0.70677567 -0.29802844 -0.4886595   0.32164472  0.42656147 -0.16595326
#   0.22552422  1.1279252   0.        ]
# action:      2  com:no_com
# reward:      -0.20515137791971788
#
# step 27
# observation: [-0.03008174 -0.22352132 -0.4856513   0.34399685  0.42956966 -0.14360112
#   0.22853239  1.1502774   0.        ]
# action:      1  com:no_com
# reward:      -0.24824372581185586
#
# step 28
# observation: [-0.5225613  -0.16764098 -0.4333952   0.36076093  0.4818258  -0.12683703
#   0.2807885   1.1670414   0.        ]
# action:      4  com:no_com
# reward:      -0.29844228829078584
#
# step 29
# observation: [-0.39192098  0.37426925 -0.3942031   0.323334    0.5210179  -0.16426395
#   0.31998062  1.1296145   0.        ]
# action:      4  com:no_com
# reward:      -0.3616791685980854
#
# step 30
# observation: [-0.29394072  0.78070194 -0.36480904  0.24526381  0.55041194 -0.24233414
#   0.3493747   1.0515443   0.        ]
# action:      2  com:no_com
# reward:      -0.363494720820896
#
# step 31
# observation: [ 0.27954444  0.58552647 -0.39276347  0.18671118  0.52245754 -0.30088678
#   0.32142025  0.9929917   0.        ]
# action:      2  com:no_com
# reward:      -0.3227326620397285
#
# step 32
# observation: [ 0.7096583   0.43914485 -0.4637293   0.1427967   0.45149168 -0.34480128
#   0.25045443  0.9490772   0.        ]
# action:      3  com:no_com
# reward:      -0.26602848284416547
#
# step 33
# observation: [ 0.5322437  -0.17064136 -0.51695365  0.15986083  0.3982673  -0.32773715
#   0.19723004  0.96614134  0.        ]
# action:      1  com:no_com
# reward:      -0.2659355261097134
#
# step 34
# observation: [-0.10081719 -0.12798102 -0.50687194  0.17265894  0.40834904 -0.31493902
#   0.20731176  0.9789394   0.        ]
# action:      1  com:no_com
# reward:      -0.31030522044900727
#
# step 35
# observation: [-0.5756129  -0.09598577 -0.44931066  0.1822575   0.46591032 -0.30534047
#   0.26487306  0.988538    0.        ]
# action:      0  com:com active
# reward:      -0.44805212419435325
#
# step 36
# observation: [-0.43170968 -0.07198933 -0.4061397   0.18945645  0.5090813  -0.29814154
#   0.30804402  0.99573696  4.        ]
# action:      4  com:no_com
# reward:      -0.41065070331606124
#
# step 37
# observation: [-0.32378224  0.446008   -0.37376148  0.14485563  0.5414595  -0.34274232
#   0.34042224  0.9511362   0.        ]
# action:      2  com:no_com
# reward:      -0.4075121447261446
#
# step 38
# observation: [ 0.25716332  0.334506   -0.3994778   0.11140504  0.5157432  -0.37619293
#   0.3147059   0.91768557  0.        ]
# action:      4  com:no_com
# reward:      -0.4501229210687224
#
# step 39
# observation: [ 0.19287248  0.7508795  -0.41876507  0.03631709  0.49645594 -0.4512809
#   0.29541865  0.8425976   0.        ]
# action:      3  com:no_com
# reward:      -0.4417097044117385
#
# step 40
# observation: [ 0.14465436  0.06315963 -0.4332305   0.03000113  0.4819905  -0.45759684
#   0.28095323  0.83628166  0.        ]
# action:      2  com:no_com
# reward:      -0.39111264686820485
#
# step 41
# observation: [ 0.60849077  0.04736972 -0.49407956  0.02526416  0.42114142 -0.4623338
#   0.22010414  0.83154464  0.        ]
# action:      3  com:no_com
# reward:      -0.3139653264702492
#
# step 42
# observation: [ 0.4563681  -0.4644727  -0.53971636  0.07171143  0.3755046  -0.41588655
#   0.17446734  0.8779919   0.        ]
# action:      1  com:no_com
# reward:      -0.29829762461622156
#
# step 43
# observation: [-0.15772393 -0.34835452 -0.52394396  0.10654688  0.39127702 -0.3810511
#   0.19023974  0.9128274   0.        ]
# action:      1  com:no_com
# reward:      -0.33127671684413523
#
# step 44
# observation: [-0.6182929  -0.2612659  -0.4621147   0.13267347  0.45310628 -0.3549245
#   0.25206903  0.938954    0.        ]
# action:      1  com:no_com
# reward:      -0.4143722798429272
#
# step 45
# observation: [-0.9637197  -0.19594942 -0.3657427   0.15226841  0.5494783  -0.33532956
#   0.348441    0.9585489   0.        ]
# action:      4  com:no_com
# reward:      -0.5239511553190501
#
# step 46
# observation: [-0.72278976  0.35303792 -0.29346374  0.11696462  0.62175727 -0.37063336
#   0.42071998  0.92324513  0.        ]
# action:      2  com:no_com
# reward:      -0.5495313374699552
#
# step 47
# observation: [-0.04209234  0.26477844 -0.28925452  0.09048677  0.6259665  -0.3971112
#   0.4249292   0.89676726  0.        ]
# action:      3  com:no_com
# reward:      -0.5304629333041817
#
# step 48
# observation: [-0.03156925 -0.30141616 -0.2860976   0.12062839  0.6291234  -0.3669696
#   0.42808613  0.9269089   0.        ]
# action:      2  com:no_com
# reward:      -0.45671802921251126
#
# step 49
# observation: [ 0.47632307 -0.22606212 -0.3337299   0.1432346   0.5814911  -0.34436336
#   0.38045382  0.9495151   0.        ]
# action:      4  com:no_com
# reward:      -0.4402988108761028
#
# step 50
# observation: [ 0.3572423   0.3304534  -0.36945412  0.11018926  0.5457669  -0.3774087
#   0.3447296   0.91646975  0.        ]
# action:      2  com:no_com
# reward:      -0.381695309416315
#
# step 51
# observation: [ 0.7679317   0.24784006 -0.44624728  0.08540525  0.4689737  -0.4021927
#   0.26793644  0.8916858   0.        ]
# action:      3  com:no_com
# reward:      -0.30671087433072153
#
# step 52
# observation: [ 0.5759488  -0.31411996 -0.5038422   0.11681725  0.41137883 -0.3707807
#   0.21034156  0.9230977   0.        ]
# action:      4  com:no_com
# reward:      -0.2933435671529151
#
# step 53
# observation: [ 0.4319616   0.26441002 -0.5470383   0.09037625  0.36818266 -0.3972217
#   0.1671454   0.89665675  0.        ]
# action:      3  com:no_com
# reward:      -0.24747944778837197
#
# step 54
# observation: [ 0.32397118 -0.3016925  -0.57943547  0.1205455   0.33578554 -0.36705247
#   0.13474828  0.926826    0.        ]
# action:      0  com:com active
# reward:      -0.3156535391328962
#
# step 55
# observation: [ 0.2429784  -0.22626936 -0.6037333   0.14317243  0.3114877  -0.34442553
#   0.11045044  0.94945294  4.        ]
# action:      1  com:no_com
# reward:      -0.22505739172068528
#
# step 56
# observation: [-0.3177662  -0.16970202 -0.57195663  0.16014263  0.3432643  -0.32745534
#   0.14222705  0.96642315  0.        ]
# action:      2  com:no_com
# reward:      -0.19960388781538702
#
# step 57
# observation: [ 0.26167536 -0.12727651 -0.5981242   0.17287028  0.3170968  -0.3147277
#   0.11605952  0.9791508   0.        ]
# action:      3  com:no_com
# reward:      -0.15360690247956324
#
# step 58
# observation: [ 0.1962565  -0.5954574  -0.61774987  0.23241602  0.29747114 -0.25518194
#   0.09643387  1.0386965   0.        ]
# action:      1  com:no_com
# reward:      -0.15504360866922381
#
# step 59
# observation: [-0.3528076  -0.44659305 -0.5824691   0.27707532  0.3327519  -0.21052264
#   0.13171463  1.0833558   0.        ]
# action:      1  com:no_com
# reward:      -0.19879381642325933
#
# step 60
# observation: [-0.7646057  -0.33494478 -0.5060085   0.3105698   0.40921247 -0.17702816
#   0.2081752   1.1168503   0.        ]
# action:      2  com:no_com
# reward:      -0.1965963122907206
#
# step 61
# observation: [-0.07345428 -0.25120857 -0.4986631   0.33569068  0.4165579  -0.15190731
#   0.21552064  1.1419711   0.        ]
# action:      2  com:no_com
# reward:      -0.15614056652200148
#
# step 62
# observation: [ 0.44490927 -0.18840644 -0.543154    0.35453132  0.37206697 -0.13306665
#   0.1710297   1.1608118   0.        ]
# action:      2  com:no_com
# reward:      -0.09749279634141719
#
# step 63
# observation: [ 0.83368194 -0.14130484 -0.6265222   0.3686618   0.28869876 -0.11893618
#   0.0876615   1.1749423   0.        ]
# action:      2  com:no_com
# reward:      -0.04277398489812816
#
# step 64
# observation: [ 1.1252614  -0.10597862 -0.73904836  0.37925965  0.17617263 -0.10833832
#  -0.02486464  1.1855402   0.        ]
# action:      1  com:no_com
# reward:      -0.030179141596242992
#
# step 65
# observation: [ 0.3439461  -0.07948396 -0.773443    0.38720804  0.14177802 -0.10038992
#  -0.05925925  1.1934886   0.        ]
# action:      0  com:com active
# reward:      -0.12236860231267023
#
# step 66
# observation: [ 0.25795957 -0.05961297 -0.7992389   0.39316934  0.11598206 -0.09442862
#  -0.08505521  1.1994499   4.        ]
# action:      1  com:no_com
# reward:      -0.029594227981168862
#
# step 67
# observation: [-0.30653033 -0.04470973 -0.7685859   0.39764032  0.14663509 -0.08995765
#  -0.05440218  1.2039208   0.        ]
# action:      4  com:no_com
# reward:      -0.04743336137855927
#
# step 68
# observation: [-0.22989774  0.4664677  -0.7455961   0.35099354  0.16962487 -0.13660441
#  -0.0314124   1.157274    0.        ]
# action:      4  com:no_com
# reward:      -0.08402125278928607
#
# step 69
# observation: [-0.1724233   0.8498508  -0.7283538   0.26600847  0.18686719 -0.22158949
#  -0.01417007  1.072289    0.        ]
# action:      4  com:no_com
# reward:      -0.15236468857854288
#
# step 70
# observation: [-0.12931748  1.1373881  -0.71542203  0.15226966  0.19979894 -0.3353283
#  -0.00123833  0.95855016  0.        ]
# action:      2  com:no_com
# reward:      -0.2023711576247844
#
# step 71
# observation: [ 0.4030119   0.85304105 -0.75572324  0.06696556  0.15949775 -0.42063242
#  -0.04153952  0.8732461   0.        ]
# action:      3  com:no_com
# reward:      -0.2055974919031111
#
# step 72
# observation: [ 0.3022589   0.13978079 -0.7859491   0.05298748  0.12927186 -0.4346105
#  -0.07176541  0.859268    0.        ]
# action:      3  com:no_com
# reward:      -0.1674633886503627
#
# step 73
# observation: [ 0.2266942  -0.3951644  -0.80861855  0.09250392  0.10660244 -0.39509404
#  -0.09443483  0.8987844   0.        ]
# action:      1  com:no_com
# reward:      -0.153046879140685
#
# step 74
# observation: [-0.32997936 -0.2963733  -0.7756206   0.12214125  0.13960038 -0.36545673
#  -0.06143689  0.92842174  0.        ]
# action:      1  com:no_com
# reward:      -0.16375137596822328
#
# step 75
# observation: [-0.7474845  -0.22227998 -0.7008722   0.14436924  0.21434882 -0.34322873
#   0.01331156  0.95064974  0.        ]
# action:      2  com:no_com
# reward:      -0.15522058892064414
#
# step 76
# observation: [-0.06061339 -0.16670999 -0.6948108   0.16104025  0.22041017 -0.32655773
#   0.0193729   0.96732074  0.        ]
# action:      1  com:no_com
# reward:      -0.1742311097094857
#
# step 77
# observation: [-0.54546005 -0.12503248 -0.6402648   0.1735435   0.27495617 -0.3140545
#   0.0739189   0.979824    0.        ]
# action:      3  com:no_com
# reward:      -0.16463151856085123
#
# step 78
# observation: [-0.40909502 -0.5937744  -0.59935534  0.23292093  0.31586567 -0.25467703
#   0.11482841  1.0392014   0.        ]
# action:      2  com:no_com
# reward:      -0.13210108344731553
#
# step 79
# observation: [ 0.19317873 -0.44533077 -0.6186732   0.27745402  0.2965478  -0.21014397
#   0.09551053  1.0837345   0.        ]
# action:      1  com:no_com
# reward:      -0.14150193932440458
#
# step 80
# observation: [-0.35511595 -0.33399808 -0.5831616   0.3108538   0.33205938 -0.17674415
#   0.13102213  1.1171343   0.        ]
# action:      2  com:no_com
# reward:      -0.11830258631520787
#
# step 81
# observation: [ 0.23366304 -0.25049856 -0.60652786  0.33590367  0.30869308 -0.1516943
#   0.10765583  1.1421841   0.        ]
# action:      2  com:no_com
# reward:      -0.0758264266056175
#
# step 82
# observation: [ 0.67524725 -0.18787391 -0.6740526   0.35469106  0.24116836 -0.1329069
#   0.0401311   1.1609715   0.        ]
# action:      2  com:no_com
# reward:      -0.0338645530374714
#
# step 83
# observation: [ 1.0064355  -0.14090544 -0.7746962   0.3687816   0.14052482 -0.11881636
#  -0.06051245  1.1750621   0.        ]
# action:      1  com:no_com
# reward:      -0.024952426623042027
#
# step 84
# observation: [ 0.2548266  -0.10567908 -0.8001788   0.3793495   0.11504216 -0.10824845
#  -0.08599511  1.18563     0.        ]
# action:      1  com:no_com
# reward:      -0.03136022223772925
#
# step 85
# observation: [-0.30888006 -0.07925931 -0.7692908   0.38727546  0.14593017 -0.10032252
#  -0.0551071   1.193556    0.        ]
# action:      0  com:com active
# reward:      -0.1375007361165592
#
# step 86
# observation: [-0.23166004 -0.05944448 -0.7461248   0.3932199   0.16909617 -0.09437808
#  -0.03194109  1.1995004   4.        ]
# action:      4  com:no_com
# reward:      -0.054348845561705356
#
# step 87
# observation: [-0.17374504  0.45541665 -0.7287503   0.34767824  0.18647067 -0.13991974
#  -0.01456659  1.1539587   0.        ]
# action:      0  com:com active
# reward:      -0.17010331805385878
#
# step 88
# observation: [-1.3030878e-01  3.4156248e-01 -7.1571946e-01  3.1352198e-01
#   1.9950156e-01 -1.7407599e-01 -1.5357146e-03  1.1198025e+00
#   4.0000000e+00]
# action:      0  com:com active
# reward:      -0.18367326702763914
#
# step 89
# observation: [-0.09773158  0.25617185 -0.70594627  0.2879048   0.20927471 -0.19969317
#   0.00823744  1.0941854   4.        ]
# action:      0  com:com active
# reward:      -0.19483740697309862
#
# step 90
# observation: [-0.07329869  0.1921289  -0.6986164   0.2686919   0.21660458 -0.21890606
#   0.01556731  1.0749724   4.        ]
# action:      4  com:no_com
# reward:      -0.12959709120534038
#
# step 91
# observation: [-0.05497401  0.6440967  -0.693119    0.20428224  0.22210199 -0.28331572
#   0.02106471  1.0105628   0.        ]
# action:      3  com:no_com
# reward:      -0.13048926652874027
#
# step 92
# observation: [-0.04123051 -0.0169275  -0.68899596  0.205975    0.22622503 -0.28162298
#   0.02518776  1.0122555   0.        ]
# action:      2  com:no_com
# reward:      -0.11075273881989336
#
# step 93
# observation: [ 0.4690771  -0.01269562 -0.7359037   0.20724455  0.17931733 -0.28035343
#  -0.02171995  1.013525    0.        ]
# action:      1  com:no_com
# reward:      -0.11575404969390837
#
# step 94
# observation: [-0.14819217 -0.00952172 -0.7210845   0.20819673  0.19413653 -0.27940124
#  -0.00690073  1.0144773   0.        ]
# action:      1  com:no_com
# reward:      -0.14281955462348447
#
# step 95
# observation: [-0.6111441  -0.00714129 -0.65997005  0.20891085  0.25525096 -0.27868712
#   0.05421368  1.0151913   0.        ]
# action:      2  com:no_com
# reward:      -0.14041282689833862
#
# step 96
# observation: [ 0.04164191 -0.00535597 -0.6641342   0.20944645  0.25108677 -0.2781515
#   0.05004949  1.0157269   0.        ]
# action:      2  com:no_com
# reward:      -0.11633455561849428
#
# step 97
# observation: [ 0.5312314  -0.00401697 -0.7172574   0.20984815  0.19796361 -0.2777498
#  -0.00307365  1.0161287   0.        ]
# action:      1  com:no_com
# reward:      -0.12029215428512327
#
# step 98
# observation: [-0.10157643 -0.00301273 -0.70709974  0.21014942  0.20812126 -0.27744853
#   0.00708399  1.0164299   0.        ]
# action:      0  com:com active
# reward:      -0.22339589315096597
#
# step 99
# observation: [-7.6182321e-02 -2.2595481e-03 -6.9948149e-01  2.1037537e-01
#   2.1573949e-01 -2.7722260e-01  1.4702221e-02  1.0166559e+00
#   4.0000000e+00]
# action:      4  com:no_com
# reward:      -0.15600525120339065
#
# step 100
# observation: [-0.05713674  0.49830535 -0.69376785  0.16054484  0.22145316 -0.32705313
#   0.02041589  0.96682537  0.        ]
# action:      3  com:no_com
# reward:      -0.14982156020638057
#
# step 101
# observation: [-0.04285255 -0.126271   -0.68948257  0.17317194  0.22573842 -0.31442603
#   0.02470115  0.97945243  0.        ]
# action:      4  com:no_com
# reward:      -0.17841273402467234
#
# step 102
# observation: [-0.03213942  0.40529674 -0.6862686   0.13264227  0.22895236 -0.3549557
#   0.02791509  0.93892276  0.        ]
# action:      3  com:no_com
# reward:      -0.16599035994022673
#
# step 103
# observation: [-0.02410456 -0.19602743 -0.68385816  0.15224501  0.23136282 -0.33535296
#   0.03032555  0.95852554  0.        ]
# action:      1  com:no_com
# reward:      -0.18300262234446063
#
# step 104
# observation: [-0.51807845 -0.14702058 -0.63205034  0.16694707  0.28317067 -0.3206509
#   0.08213339  0.97322756  0.        ]
# action:      2  com:no_com
# reward:      -0.1698656816471797
#
# step 105
# observation: [ 0.11144118 -0.11026543 -0.64319444  0.17797361  0.27202654 -0.30962434
#   0.07098927  0.9842541   0.        ]
# action:      1  com:no_com
# reward:      -0.18920240223306548
#
# step 106
# observation: [-0.41641912 -0.08269908 -0.60155255  0.18624352  0.31366846 -0.30135444
#   0.11263119  0.992524    0.        ]
# action:      2  com:no_com
# reward:      -0.17408065694349795
#
# step 107
# observation: [ 0.18768567 -0.06202431 -0.6203211   0.19244595  0.29489988 -0.295152
#   0.09386262  0.9987264   0.        ]
# action:      1  com:no_com
# reward:      -0.19383452601574408
#
# step 108
# observation: [-0.35923576 -0.04651823 -0.58439755  0.19709776  0.33082345 -0.2905002
#   0.1297862   1.0033783   0.        ]
# action:      3  com:no_com
# reward:      -0.18417098206135774
#
# step 109
# observation: [-0.26942682 -0.5348887  -0.5574548   0.25058663  0.35776615 -0.23701133
#   0.15672888  1.0568671   0.        ]
# action:      0  com:com active
# reward:      -0.28163121826841164
#
# step 110
# observation: [-0.20207012 -0.4011665  -0.53724784  0.2907033   0.37797314 -0.19689468
#   0.17693588  1.0969838   4.        ]
# action:      2  com:no_com
# reward:      -0.14556174493069587
#
# step 111
# observation: [ 0.3484474  -0.3008749  -0.5720926   0.32079077  0.3431284  -0.16680719
#   0.14209114  1.1270713   0.        ]
# action:      1  com:no_com
# reward:      -0.15549085475797422
#
# step 112
# observation: [-0.23866443 -0.22565615 -0.5482261   0.3433564   0.36699486 -0.14424157
#   0.16595758  1.1496369   0.        ]
# action:      0  com:com active
# reward:      -0.26435363070297546
#
# step 113
# observation: [-0.17899832 -0.16924211 -0.5303263   0.3602806   0.3848947  -0.12731737
#   0.18385743  1.1665611   4.        ]
# action:      1  com:no_com
# reward:      -0.2141291369864542
#
# step 114
# observation: [-0.63424873 -0.1269316  -0.46690142  0.37297377  0.44831955 -0.1146242
#   0.2472823   1.1792543   0.        ]
# action:      4  com:no_com
# reward:      -0.26996247853430405
#
# step 115
# observation: [-0.47568655  0.4048013  -0.41933277  0.33249363  0.4958882  -0.15510434
#   0.29485095  1.1387742   0.        ]
# action:      2  com:no_com
# reward:      -0.2663016249920172
#
# step 116
# observation: [ 0.14323509  0.30360097 -0.43365628  0.30213353  0.4815647  -0.18546444
#   0.28052744  1.108414    0.        ]
# action:      2  com:no_com
# reward:      -0.22045283129193238
#
# step 117
# observation: [ 0.6074263   0.22770074 -0.49439892  0.27936345  0.42082208 -0.2082345
#   0.21978481  1.085644    0.        ]
# action:      1  com:no_com
# reward:      -0.23161593474858214
#
# step 118
# observation: [-0.04443027  0.17077555 -0.48995587  0.26228592  0.4252651  -0.22531207
#   0.22422783  1.0685664   0.        ]
# action:      2  com:no_com
# reward:      -0.20003721560219603
#
# step 119
# observation: [ 0.4666773   0.12808166 -0.5366236   0.24947774  0.37859738 -0.23812023
#   0.1775601   1.0557582   0.        ]
# action:      2  com:no_com
# reward:      -0.14756729663428134
#
# step 120
# observation: [ 0.85000795  0.09606124 -0.6216244   0.2398716   0.29359657 -0.24772635
#   0.09255931  1.0461521   0.        ]
# action:      1  com:no_com
# reward:      -0.14330356010346662
#
# step 121
# observation: [ 0.13750598  0.07204594 -0.635375    0.23266701  0.27984598 -0.25493094
#   0.07880871  1.0389475   0.        ]
# action:      3  com:no_com
# reward:      -0.11688861133394753
#
# step 122
# observation: [ 0.10312948 -0.44596556 -0.64568794  0.27726358  0.26953304 -0.21033439
#   0.06849577  1.0835441   0.        ]
# action:      4  com:no_com
# reward:      -0.12001606009555128
#
# step 123
# observation: [ 0.07734711  0.16552584 -0.65342265  0.26071098  0.26179832 -0.22688697
#   0.06076105  1.0669914   0.        ]
# action:      2  com:no_com
# reward:      -0.09970004876627286
#
# step 124
# observation: [ 0.55801034  0.12414438 -0.7092237   0.24829656  0.20599729 -0.23930141
#   0.00496002  1.0545771   0.        ]
# action:      3  com:no_com
# reward:      -0.06639090002783796
#
# step 125
# observation: [ 0.41850775 -0.4068917  -0.7510745   0.28898573  0.16414651 -0.19861224
#  -0.03689076  1.0952662   0.        ]
# action:      1  com:no_com
# reward:      -0.061656694908983
#
# step 126
# observation: [-0.18611918 -0.30516878 -0.7324626   0.3195026   0.18275844 -0.16809537
#  -0.01827884  1.1257831   0.        ]
# action:      2  com:no_com
# reward:      -0.04261126378465438
#
# step 127
# observation: [ 0.3604106  -0.22887659 -0.7685036   0.34239027  0.14671737 -0.1452077
#  -0.0543199   1.1486708   0.        ]
# action:      1  com:no_com
# reward:      -0.04518827656645215
#
# step 128
# observation: [-0.22969204 -0.17165744 -0.7455344   0.35955602  0.16968657 -0.12804197
#  -0.03135069  1.1658365   0.        ]
# action:      4  com:no_com
# reward:      -0.06221700084829078
#
# step 129
# observation: [-0.17226903  0.37125692 -0.7283075   0.3224303   0.18691348 -0.16516766
#  -0.01412379  1.1287109   0.        ]
# action:      4  com:no_com
# reward:      -0.09898828297892262
#
# step 130
# observation: [-0.12920177  0.7784427  -0.71538734  0.24458605  0.19983365 -0.24301192
#  -0.00120361  1.0508666   0.        ]
# action:      2  com:no_com
# reward:      -0.11628685884811123
#
# step 131
# observation: [ 0.40309867  0.583832   -0.7556972   0.18620284  0.15952379 -0.30139512
#  -0.04151348  0.9924833   0.        ]
# action:      1  com:no_com
# reward:      -0.15129637648882113
#
# step 132
# observation: [-0.197676    0.43787402 -0.7359296   0.14241545  0.17929138 -0.34518254
#  -0.02174588  0.94869596  0.        ]
# action:      2  com:no_com
# reward:      -0.16367118027592573
#
# step 133
# observation: [ 0.351743    0.3284055  -0.7711039   0.10957489  0.14411709 -0.3780231
#  -0.05692018  0.9158554   0.        ]
# action:      3  com:no_com
# reward:      -0.13822633397346737
#
# step 134
# observation: [ 0.26380724 -0.25369588 -0.79748464  0.13494448  0.11773636 -0.3526535
#  -0.0833009   0.941225    0.        ]
# action:      1  com:no_com
# reward:      -0.13319595148712726
#
# step 135
# observation: [-0.30214456 -0.1902719  -0.76727015  0.15397167  0.14795081 -0.3336263
#  -0.05308645  0.96025217  0.        ]
# action:      1  com:no_com
# reward:      -0.15065769878385543
#
# step 136
# observation: [-0.7266084  -0.14270392 -0.69460934  0.16824207  0.22061166 -0.3193559
#   0.01957439  0.9745226   0.        ]
# action:      1  com:no_com
# reward:      -0.20096149344554481
#
# step 137
# observation: [-1.0449563  -0.10702795 -0.5901137   0.17894486  0.32510728 -0.30865312
#   0.12407003  0.9852254   0.        ]
# action:      4  com:no_com
# reward:      -0.2857339175494054
#
# step 138
# observation: [-0.7837172   0.41972905 -0.511742    0.13697195  0.403479   -0.35062602
#   0.20244175  0.94325244  0.        ]
# action:      3  com:no_com
# reward:      -0.3239764716038895
#
# step 139
# observation: [-0.5877879  -0.18520322 -0.45296317  0.15549228  0.4622578  -0.3321057
#   0.26122054  0.9617728   0.        ]
# action:      2  com:no_com
# reward:      -0.30950900488575683
#
# step 140
# observation: [ 0.05915906 -0.13890241 -0.45887908  0.16938251  0.4563419  -0.31821546
#   0.25530463  0.975663    0.        ]
# action:      0  com:com active
# reward:      -0.39895757182259517
#
# step 141
# observation: [ 0.04436929 -0.10417681 -0.46331602  0.1798002   0.45190498 -0.30779776
#   0.2508677   0.9860807   4.        ]
# action:      3  com:no_com
# reward:      -0.26371382731598797
#
# step 142
# observation: [ 0.03327697 -0.5781326  -0.46664372  0.23761345  0.44857728 -0.24998452
#   0.24754001  1.0438939   0.        ]
# action:      2  com:no_com
# reward:      -0.19957426750162496
#
# step 143
# observation: [ 0.5249577  -0.43359944 -0.51913947  0.2809734   0.3960815  -0.20662457
#   0.19504423  1.0872539   0.        ]
# action:      1  com:no_com
# reward:      -0.195725171876742
#
# step 144
# observation: [-0.10628171 -0.3251996  -0.5085113   0.31349337  0.40670967 -0.1741046
#   0.20567241  1.1197739   0.        ]
# action:      1  com:no_com
# reward:      -0.2383427190216033
#
# step 145
# observation: [-0.57971126 -0.24389969 -0.45054018  0.33788332  0.4646808  -0.14971463
#   0.26364353  1.1441638   0.        ]
# action:      4  com:no_com
# reward:      -0.2911397183810348
#
# step 146
# observation: [-0.43478346  0.31707522 -0.40706185  0.3061758   0.50815916 -0.18142216
#   0.30712187  1.1124563   0.        ]
# action:      2  com:no_com
# reward:      -0.28296132762213055
#
# step 147
# observation: [ 0.1739124   0.23780642 -0.42445308  0.28239515  0.4907679  -0.2052028
#   0.28973064  1.0886756   0.        ]
# action:      2  com:no_com
# reward:      -0.23269430312288508
#
# step 148
# observation: [ 0.6304343   0.17835481 -0.48749653  0.2645597   0.42772448 -0.22303829
#   0.22668721  1.0708402   0.        ]
# action:      0  com:com active
# reward:      -0.30062804406149424
#
# step 149
# observation: [ 0.47282574  0.13376611 -0.5347791   0.25118306  0.3804419  -0.2364149
#   0.17940463  1.0574635   4.        ]
# action:      0  com:com active
# reward:      -0.27974748000403793
#
# step 150
# observation: [ 0.3546193   0.10032459 -0.57024103  0.24115062  0.34497997 -0.24644735
#   0.1439427   1.0474311   4.        ]
# action:      2  com:no_com
# reward:      -0.13653134012516166
#
# step 151
# observation: [ 0.76596445  0.07524344 -0.6468375   0.23362628  0.26838353 -0.2539717
#   0.06734626  1.0399067   0.        ]
# action:      1  com:no_com
# reward:      -0.1354876205808343
#
# step 152
# observation: [ 0.07447335  0.05643258 -0.6542848   0.22798301  0.2609362  -0.25961494
#   0.05989892  1.0342635   0.        ]
# action:      4  com:no_com
# reward:      -0.1637041640760763
#
# step 153
# observation: [ 0.05585502  0.5423244  -0.6598703   0.17375056  0.25535068 -0.3138474
#   0.05431342  0.9800311   0.        ]
# action:      2  com:no_com
# reward:      -0.16615163232991126
#
# step 154
# observation: [ 5.4189128e-01  4.0674332e-01 -7.1405941e-01  1.3307624e-01
#   2.0116156e-01 -3.5452172e-01  1.2429596e-04  9.3935674e-01
#   0.0000000e+00]
# action:      3  com:no_com
# reward:      -0.13800999277196774
#
# step 155
# observation: [ 0.40641844 -0.1949425  -0.75470126  0.15257049  0.16051972 -0.3350275
#  -0.04051755  0.958851    0.        ]
# action:      3  com:no_com
# reward:      -0.0900298020843967
#
# step 156
# observation: [ 0.30481383 -0.64620686 -0.78518265  0.21719117  0.13003834 -0.27040678
#  -0.07099893  1.0234717   0.        ]
# action:      1  com:no_com
# reward:      -0.07396263309526482
#
# step 157
# observation: [-0.27138963 -0.48465517 -0.7580437   0.26565668  0.1571773  -0.22194128
#  -0.04385997  1.0719372   0.        ]
# action:      2  com:no_com
# reward:      -0.050708730700700325
#
# step 158
# observation: [ 0.29645777 -0.36349136 -0.78768945  0.30200583  0.12753151 -0.18559214
#  -0.07350574  1.1082864   0.        ]
# action:      4  com:no_com
# reward:      -0.05448900576784036
#
# step 159
# observation: [ 0.22234334  0.22738147 -0.8099238   0.27926767  0.10529719 -0.20833029
#  -0.09574008  1.0855482   0.        ]
# action:      2  com:no_com
# reward:      -0.05228951653979531
#
# step 160
# observation: [ 0.6667575   0.1705361  -0.87659955  0.26221406  0.03862144 -0.2253839
#  -0.16241583  1.0684946   0.        ]
# action:      1  com:no_com
# reward:      -0.05821799356115477
#
# step 161
# observation: [ 6.8126785e-05  1.2790208e-01 -8.7660635e-01  2.4942386e-01
#   3.8614623e-02 -2.3817411e-01 -1.6242264e-01  1.0557044e+00
#   0.0000000e+00]
# action:      1  com:no_com
# reward:      -0.06924001378353051
#
# step 162
# observation: [-0.49994892  0.09592656 -0.82661146  0.23983121  0.08860951 -0.24776676
#  -0.11242776  1.0461117   0.        ]
# action:      1  com:no_com
# reward:      -0.09601845143349164
#
# step 163
# observation: [-0.8749617   0.07194492 -0.7391153   0.23263672  0.17610568 -0.25496125
#  -0.02493159  1.0389172   0.        ]
# action:      4  com:no_com
# reward:      -0.15475387577576674
#
# step 164
# observation: [-0.6562213   0.5539587  -0.6734932   0.17724085  0.24172781 -0.31035712
#   0.04069054  0.98352134  0.        ]
# action:      2  com:no_com
# reward:      -0.1818906464116211
#
# step 165
# observation: [ 0.00783406  0.41546902 -0.6742766   0.13569394  0.2409444  -0.35190403
#   0.03990714  0.94197446  0.        ]
# action:      0  com:com active
# reward:      -0.3045095952678035
#
# step 166
# observation: [ 0.00587554  0.31160176 -0.6748641   0.10453377  0.24035685 -0.3830642
#   0.03931958  0.9108143   4.        ]
# action:      2  com:no_com
# reward:      -0.2012570224054734
#
# step 167
# observation: [ 0.50440663  0.23370132 -0.7253048   0.08116364  0.18991618 -0.40643433
#  -0.01112109  0.88744414  0.        ]
# action:      1  com:no_com
# reward:      -0.22058234223581036
#
# step 168
# observation: [-0.121695    0.175276   -0.7131353   0.06363603  0.20208569 -0.42396194
#   0.00104842  0.86991656  0.        ]
# action:      3  com:no_com
# reward:      -0.19446316796610022
#
# step 169
# observation: [-0.09127126 -0.368543   -0.70400816  0.10049034  0.21121281 -0.38710764
#   0.01017554  0.9067708   0.        ]
# action:      0  com:com active
# reward:      -0.27676581362806796
#
# step 170
# observation: [-0.06845344 -0.27640724 -0.6971628   0.12813106  0.21805815 -0.3594669
#   0.01702088  0.9344116   4.        ]
# action:      1  com:no_com
# reward:      -0.1893762786962472
#
# step 171
# observation: [-0.5513401  -0.20730545 -0.6420288   0.1488616   0.27319217 -0.33873636
#   0.07215489  0.9551421   0.        ]
# action:      1  com:no_com
# reward:      -0.23734213163463658
#
# step 172
# observation: [-0.9135051  -0.15547907 -0.5506783   0.16440952  0.36454266 -0.32318845
#   0.1635054   0.97069     0.        ]
# action:      0  com:com active
# reward:      -0.3845865026280477
#
# step 173
# observation: [-0.6851288  -0.11660931 -0.48216543  0.17607045  0.43305555 -0.31152752
#   0.23201828  0.98235095  4.        ]
# action:      4  com:no_com
# reward:      -0.3591373277333695
#
# step 174
# observation: [-0.5138466   0.41254303 -0.43078077  0.13481614  0.4844402  -0.35278183
#   0.28340295  0.94109666  0.        ]
# action:      3  com:no_com
# reward:      -0.38487746116583466
#
# step 175
# observation: [-0.38538495 -0.19059274 -0.39224228  0.15387541  0.5229787  -0.33372256
#   0.32194144  0.9601559   0.        ]
# action:      3  com:no_com
# reward:      -0.3771658705915709
#
# step 176
# observation: [-0.28903872 -0.6429446  -0.3633384   0.21816987  0.55188257 -0.2694281
#   0.3508453   1.0244504   0.        ]
# action:      2  com:no_com
# reward:      -0.3230482193202543
#
# step 177
# observation: [ 0.28322098 -0.4822084  -0.3916605   0.2663907   0.52356046 -0.22120725
#   0.3225232   1.0726712   0.        ]
# action:      4  com:no_com
# reward:      -0.3075688434044916
#
# step 178
# observation: [ 0.21241572  0.13834369 -0.4129021   0.25255635  0.5023189  -0.23504162
#   0.30128163  1.0588368   0.        ]
# action:      2  com:no_com
# reward:      -0.25066394405968884
#
# step 179
# observation: [ 0.6593118   0.10375777 -0.47883326  0.24218057  0.43638772 -0.2454174
#   0.23535046  1.0484611   0.        ]
# action:      2  com:no_com
# reward:      -0.177637968273824
#
# step 180
# observation: [ 0.9944838   0.07781833 -0.57828164  0.23439874  0.33693933 -0.25319922
#   0.13590208  1.0406792   0.        ]
# action:      3  com:no_com
# reward:      -0.11252500711526973
#
# step 181
# observation: [ 0.7458629  -0.44163626 -0.6528679   0.27856237  0.26235306 -0.2090356
#   0.06131578  1.0848429   0.        ]
# action:      1  com:no_com
# reward:      -0.09669314114496208
#
# step 182
# observation: [ 0.05939716 -0.33122718 -0.65880764  0.3116851   0.25641334 -0.17591289
#   0.05537607  1.1179656   0.        ]
# action:      2  com:no_com
# reward:      -0.06360965518488693
#
# step 183
# observation: [ 5.4454786e-01 -2.4842039e-01 -7.1326244e-01  3.3652711e-01
#   2.0195855e-01 -1.5107085e-01  9.2127913e-04  1.1428076e+00
#   0.0000000e+00]
# action:      2  com:no_com
# reward:      -0.029887261796076123
#
# step 184
# observation: [ 0.9084109  -0.1863153  -0.80410355  0.35515866  0.11111745 -0.13243932
#  -0.08991981  1.1614392   0.        ]
# action:      1  com:no_com
# reward:      -0.02268062988649431
#
# step 185
# observation: [ 0.18130818 -0.13973647 -0.82223433  0.3691323   0.09298664 -0.11846567
#  -0.10805063  1.1754128   0.        ]
# action:      1  com:no_com
# reward:      -0.028402244444471147
#
# step 186
# observation: [-0.36401886 -0.10480236 -0.78583246  0.37961254  0.12938853 -0.10798544
#  -0.07164874  1.185893    0.        ]
# action:      2  com:no_com
# reward:      -0.021407810571149495
#
# step 187
# observation: [ 0.22698586 -0.07860176 -0.80853105  0.38747272  0.10668994 -0.10012526
#  -0.09434733  1.1937532   0.        ]
# action:      1  com:no_com
# reward:      -0.028385908409477256
#
# step 188
# observation: [-0.3297606  -0.05895133 -0.775555    0.39336783  0.139666   -0.09423012
#  -0.06137127  1.1996484   0.        ]
# action:      4  com:no_com
# reward:      -0.04657321180011041
#
# step 189
# observation: [-0.24732046  0.4557865  -0.75082296  0.3477892   0.16439804 -0.13980877
#  -0.03663922  1.1540697   0.        ]
# action:      4  com:no_com
# reward:      -0.08364239316946107
#
# step 190
# observation: [-0.18549034  0.8418399  -0.7322739   0.2636052   0.18294708 -0.22399276
#  -0.01809019  1.0698857   0.        ]
# action:      4  com:no_com
# reward:      -0.15241055609286697
#
# step 191
# observation: [-0.13911776  1.13138    -0.71836215  0.15046722  0.19685885 -0.33713076
#  -0.00417841  0.9567477   0.        ]
# action:      3  com:no_com
# reward:      -0.18134254042404058
#
# step 192
# observation: [-0.10433832  0.34853494 -0.7079283   0.11561372  0.20729269 -0.37198424
#   0.00625542  0.9218942   0.        ]
# action:      3  com:no_com
# reward:      -0.1674663572384179
#
# step 193
# observation: [-0.07825374 -0.2385988  -0.7001029   0.1394736   0.21511807 -0.34812436
#   0.0140808   0.9457541   0.        ]
# action:      3  com:no_com
# reward:      -0.12736384502930256
#
# step 194
# observation: [-0.05869031 -0.6789491  -0.6942339   0.20736851  0.2209871  -0.28022945
#   0.01994983  1.013649    0.        ]
# action:      1  com:no_com
# reward:      -0.12842131313894833
#
# step 195
# observation: [-0.54401773 -0.50921184 -0.63983214  0.2582897   0.27538887 -0.22930828
#   0.0743516   1.0645702   0.        ]
# action:      2  com:no_com
# reward:      -0.1073830768004326
#
# step 196
# observation: [ 0.0919867  -0.38190886 -0.6490308   0.29648057  0.2661902  -0.19111739
#   0.06515293  1.102761    0.        ]
# action:      0  com:com active
# reward:      -0.19362979623120935
#
# step 197
# observation: [ 0.06899003 -0.28643164 -0.6559298   0.32512376  0.2592912  -0.16247423
#   0.05825393  1.1314043   4.        ]
# action:      0  com:com active
# reward:      -0.18445412143941514
#
# step 198
# observation: [ 0.05174252 -0.21482374 -0.661104    0.3466061   0.25411695 -0.14099185
#   0.05307967  1.1528866   4.        ]
# action:      1  com:no_com
# reward:      -0.10573683866917861
#
# step 199
# observation: [-0.4611931  -0.1611178  -0.61498475  0.3627179   0.30023625 -0.12488007
#   0.09919898  1.1689984   0.        ]
# action:      4  com:no_com
# reward:      -0.13861088673534083
#
# step 0
# observation: [ 0.          0.         -1.2894104   0.42169482 -0.39855602  0.46266785
#  -1.4733071   0.92734605  0.        ]
# action:      1  com:no_com
# reward:      -0.33555285417701386
#
# step 1
# observation: [-0.5         0.         -1.2394103   0.42169482 -0.34855604  0.46266785
#  -1.4233072   0.92734605  0.        ]
# action:      1  com:no_com
# reward:      -0.28221179922733214
#
# step 2
# observation: [-0.875       0.         -1.1519103   0.42169482 -0.26105604  0.46266785
#  -1.3358072   0.92734605  0.        ]
# action:      1  com:no_com
# reward:      -0.23521173331168133
#
# step 3
# observation: [-1.15625     0.         -1.0362853   0.42169482 -0.14543103  0.46266785
#  -1.2201822   0.92734605  0.        ]
# action:      4  com:no_com
# reward:      -0.17374189487533612
#
# step 4
# observation: [-0.8671875   0.5        -0.94956654  0.37169483 -0.05871228  0.41266787
#  -1.1334634   0.87734604  0.        ]
# action:      4  com:no_com
# reward:      -0.10577416583020845
#
# step 5
# observation: [-0.6503906   0.875      -0.8845275   0.28419483  0.00632678  0.32516786
#  -1.0684243   0.789846    0.        ]
# action:      4  com:no_com
# reward:      -0.04694489064322178
#
# step 6
# observation: [-0.48779297  1.15625    -0.8357482   0.16856982  0.05510608  0.20954286
#  -1.0196451   0.67422104  0.        ]
# action:      2  com:no_com
# reward:      -0.016823864440809248
#
# step 7
# observation: [ 0.13415527  0.8671875  -0.8491637   0.08185107  0.04169055  0.12282411
#  -1.0330606   0.5875023   0.        ]
# action:      1  com:no_com
# reward:      -0.010002390455762896
#
# step 8
# observation: [-0.39938354  0.6503906  -0.8092254   0.01681201  0.08162891  0.05778505
#  -0.9931222   0.5224632   0.        ]
# action:      2  com:no_com
# reward:      -0.003873529307289455
#
# step 9
# observation: [ 0.20046234  0.48779297 -0.8292716  -0.03196729  0.06158267  0.00900575
#  -1.0131685   0.47368392  0.        ]
# action:      1  com:no_com
# reward:      -0.01008210188670199
#
# step 10
# observation: [-0.34965324  0.36584473 -0.7943063  -0.06855176  0.096548   -0.02757872
#  -0.9782031   0.43709943  0.        ]
# action:      3  com:no_com
# reward:      -0.015098133023294718
#
# step 11
# observation: [-0.26223993 -0.22561646 -0.7680823  -0.04599012  0.12277199 -0.00501708
#  -0.95197916  0.4596611   0.        ]
# action:      4  com:no_com
# reward:      -0.02174044299048531
#
# step 12
# observation: [-0.19667995  0.33078766 -0.7484143  -0.07906888  0.14243999 -0.03809584
#  -0.9323111   0.4265823   0.        ]
# action:      1  com:no_com
# reward:      -0.046885131913745444
#
# step 13
# observation: [-0.64750993  0.24809074 -0.6836633  -0.10387795  0.20719099 -0.06290492
#  -0.86756015  0.40177324  0.        ]
# action:      4  com:no_com
# reward:      -0.08270555925835779
#
# step 14
# observation: [-0.48563248  0.68606806 -0.63510007 -0.17248476  0.25575423 -0.13151172
#  -0.8189969   0.33316645  0.        ]
# action:      4  com:no_com
# reward:      -0.13964074603817567
#
# step 15
# observation: [-0.36422434  1.014551   -0.59867764 -0.27393988  0.29217666 -0.23296683
#  -0.7825745   0.23171133  0.        ]
# action:      3  com:no_com
# reward:      -0.16918721891922556
#
# step 16
# observation: [-0.27316827  0.26091328 -0.57136077 -0.3000312   0.3194935  -0.25905815
#  -0.7552576   0.20562     0.        ]
# action:      3  com:no_com
# reward:      -0.1678573019387114
#
# step 17
# observation: [-0.2048762  -0.30431503 -0.55087316 -0.2695997   0.3399811  -0.22862665
#  -0.73477     0.23605151  0.        ]
# action:      0  com:com active
# reward:      -0.2686262516315253
#
# step 18
# observation: [-0.15365715 -0.22823627 -0.53550744 -0.24677606  0.35534683 -0.20580302
#  -0.7194043   0.25887513  5.        ]
# action:      1  com:no_com
# reward:      -0.20938366814272333
#
# step 19
# observation: [-0.61524284 -0.17117721 -0.47398317 -0.22965834  0.4168711  -0.1886853
#  -0.65788     0.27599287  0.        ]
# action:      4  com:no_com
# reward:      -0.26538914024145827
#
# step 20
# observation: [-0.46143216  0.37161708 -0.42783996 -0.26682004  0.46301433 -0.225847
#  -0.6117368   0.23883115  0.        ]
# action:      0  com:com active
# reward:      -0.4120003672447071
#
# step 21
# observation: [-0.3460741   0.2787128  -0.39323255 -0.29469132  0.49762174 -0.2537183
#  -0.57712936  0.21095987  5.        ]
# action:      0  com:com active
# reward:      -0.44955029414481773
#
# step 22
# observation: [-0.25955558  0.20903462 -0.367277   -0.3155948   0.5235773  -0.27462175
#  -0.5511738   0.1900564   5.        ]
# action:      1  com:no_com
# reward:      -0.4359748583771978
#
# step 23
# observation: [-0.6946667   0.15677597 -0.29781032 -0.3312724   0.593044   -0.29029936
#  -0.48170716  0.17437881  0.        ]
# action:      2  com:no_com
# reward:      -0.4454351039969232
#
# step 24
# observation: [-0.02100001  0.11758197 -0.29571033 -0.3430306   0.595144   -0.30205753
#  -0.47960716  0.16262062  0.        ]
# action:      3  com:no_com
# reward:      -0.42412991670959727
#
# step 25
# observation: [-0.01575001 -0.41181353 -0.2941353  -0.30184925  0.59671897 -0.2608762
#  -0.47803214  0.20380196  0.        ]
# action:      3  com:no_com
# reward:      -0.3898811375932272
#
# step 26
# observation: [-0.01181251 -0.8088601  -0.29295406 -0.22096322  0.5979002  -0.17999019
#  -0.4768509   0.28468797  0.        ]
# action:      1  com:no_com
# reward:      -0.43516209369655184
#
# step 27
# observation: [-0.5088594  -0.6066451  -0.24206813 -0.1602987   0.6487861  -0.11932567
#  -0.42596495  0.3453525   0.        ]
# action:      2  com:no_com
# reward:      -0.4111565492129791
#
# step 28
# observation: [ 0.11835546 -0.45498383 -0.2539037  -0.11480033  0.6369506  -0.07382729
#  -0.43780053  0.39085087  0.        ]
# action:      2  com:no_com
# reward:      -0.3357458609394342
#
# step 29
# observation: [ 0.5887666  -0.34123787 -0.31278032 -0.08067654  0.578074   -0.0397035
#  -0.49667716  0.42497465  0.        ]
# action:      2  com:no_com
# reward:      -0.23437424738169468
#
# step 30
# observation: [ 0.94157493 -0.2559284  -0.40693784 -0.0550837   0.48391646 -0.01411066
#  -0.5908347   0.4505675   0.        ]
# action:      3  com:no_com
# reward:      -0.17384975754388338
#
# step 31
# observation: [ 0.7061812  -0.6919463  -0.47755596  0.01411093  0.41329834  0.05508397
#  -0.6614528   0.51976216  0.        ]
# action:      3  com:no_com
# reward:      -0.15448383028007015
#
# step 32
# observation: [ 0.5296359  -1.0189598  -0.53051955  0.1160069   0.36033475  0.15697995
#  -0.7144164   0.6216581   0.        ]
# action:      4  com:no_com
# reward:      -0.13642835234592054
#
# step 33
# observation: [ 0.39722693 -0.2642198  -0.5702422   0.14242887  0.32061204  0.18340193
#  -0.75413907  0.6480801   0.        ]
# action:      3  com:no_com
# reward:      -0.14869585209337377
#
# step 34
# observation: [ 0.2979202  -0.6981648  -0.60003424  0.21224536  0.29082003  0.2532184
#  -0.7839311   0.7178966   0.        ]
# action:      0  com:com active
# reward:      -0.26545897849932254
#
# step 35
# observation: [ 0.22344016 -0.52362365 -0.6223783   0.26460773  0.268476    0.30558077
#  -0.8062751   0.7702589   4.        ]
# action:      2  com:no_com
# reward:      -0.15961342992912603
#
# step 36
# observation: [ 0.6675801  -0.39271772 -0.68913627  0.3038795   0.201718    0.34485254
#  -0.8730331   0.8095307   0.        ]
# action:      1  com:no_com
# reward:      -0.18076777992213955
#
# step 37
# observation: [ 6.8508374e-04 -2.9453829e-01 -6.8920481e-01  3.3333334e-01
#   2.0164950e-01  3.7430638e-01 -8.7310165e-01  8.3898455e-01
#   0.0000000e+00]
# action:      4  com:no_com
# reward:      -0.1606325047291668
#
# step 38
# observation: [ 5.1381282e-04  2.7909628e-01 -6.8925619e-01  3.0542371e-01
#   2.0159812e-01  3.4639674e-01 -8.7315303e-01  8.1107491e-01
#   0.0000000e+00]
# action:      4  com:no_com
# reward:      -0.1165069678220168
#
# step 39
# observation: [ 3.8535963e-04  7.0932221e-01 -6.8929470e-01  2.3449148e-01
#   2.0155957e-01  2.7546453e-01 -8.7319154e-01  7.4014270e-01
#   0.0000000e+00]
# action:      2  com:no_com
# reward:      -0.0723634355323453
#
# step 40
# observation: [ 0.500289    0.53199166 -0.7393236   0.18129231  0.15153068  0.22226536
#  -0.92322046  0.68694353  0.        ]
# action:      1  com:no_com
# reward:      -0.06015630440035774
#
# step 41
# observation: [-0.12478323  0.39899373 -0.72684526  0.14139295  0.164009    0.18236598
#  -0.9107421   0.6470441   0.        ]
# action:      1  com:no_com
# reward:      -0.07313154550103086
#
# step 42
# observation: [-0.5935874   0.2992453  -0.66748655  0.11146841  0.22336775  0.15244146
#  -0.8513834   0.6171196   0.        ]
# action:      0  com:com active
# reward:      -0.18866283227530675
#
# step 43
# observation: [-0.44519058  0.22443397 -0.6229675   0.08902501  0.2678868   0.12999806
#  -0.8068643   0.5946762   4.        ]
# action:      4  com:no_com
# reward:      -0.09475716570117786
#
# step 44
# ...
# action:      0  com:com active
# reward:      -1.1502663929585266
#
# step 118
# observation: [-0.11644674  0.7780364  -0.08915625 -1.0209396  -0.20837559  0.3677193
#   0.0794979   0.7101191   3.        ]
# action:      2  com:no_com
# reward:      -1.1818819081844023
#
# step 119
# observation: [ 0.41266495  0.5835273  -0.13042274 -1.0792923  -0.24964209  0.30936655
#   0.0382314   0.65176636  0.        ]
# action:      2  com:no_com
# reward:      -1.3059350097108444
#
# step 120
# observation: [ 0.8094987   0.43764547 -0.21137261 -1.1230568  -0.33059195  0.265602
#  -0.04271847  0.6080018   0.        ]
# action:      1  com:no_com
# reward:      -1.3853808690490401
#
# step 121
# observation: [ 0.10712403  0.3282341  -0.22208501 -1.1558802  -0.34130436  0.2327786
#  -0.05343087  0.57517844  0.        ]
# action:      1  com:no_com
# reward:      -1.4260180045381619
#
# step 122
# observation: [-0.419657    0.24617557 -0.18011932 -1.1804978  -0.29933867  0.20816103
#  -0.01146518  0.5505609   0.        ]
# action:      3  com:no_com
# reward:      -1.3422066366245606
#
# step 123
# observation: [-0.31474274 -0.31536832 -0.14864504 -1.148961   -0.26786438  0.23969786
#   0.0200091   0.5820977   0.        ]
# action:      1  com:no_com
# reward:      -1.271949753574988
#
# step 124
# observation: [-0.73605704 -0.23652624 -0.07503934 -1.1253084  -0.19425869  0.2633505
#   0.0936148   0.6057503   0.        ]
# action:      2  com:no_com
# reward:      -1.2315857335793197
#
# step 125
# observation: [-0.05204279 -0.17739467 -0.06983507 -1.1075689  -0.1890544   0.28108996
#   0.09881908  0.6234898   0.        ]
# action:      3  com:no_com
# reward:      -1.0948348692315604
#
# step 126
# observation: [-0.03903209 -0.63304603 -0.06593186 -1.0442643  -0.18515119  0.34439456
#   0.10272229  0.6867944   0.        ]
# action:      1  com:no_com
# reward:      -0.99375107980619
#
# step 127
# observation: [-0.52927405 -0.4747845  -0.01300445 -0.9967858  -0.13222378  0.391873
#   0.15564969  0.73427284  0.        ]
# action:      4  com:no_com
# reward:      -1.0231912972804096
#
# step 128
# observation: [-0.39695555  0.14391162  0.02669111 -1.011177   -0.09252823  0.37748185
#   0.19534525  0.71988165  0.        ]
# action:      2  com:no_com
# reward:      -1.0444651640028222
#
# step 129
# observation: [ 0.20228334  0.10793371  0.00646277 -1.0219704  -0.11275657  0.36668846
#   0.17511691  0.7090883   0.        ]
# action:      4  com:no_com
# reward:      -1.1666170600104693
#
# step 130
# observation: [ 0.1517125   0.58095026 -0.00870848 -1.0800654  -0.12792781  0.30859345
#   0.15994567  0.6509933   0.        ]
# action:      2  com:no_com
# reward:      -1.2674714974001322
#
# step 131
# observation: [ 0.6137844   0.43571272 -0.07008691 -1.1236366  -0.18930626  0.2650222
#   0.09856723  0.607422    0.        ]
# action:      4  com:no_com
# reward:      -1.4686801567404772
#
# step 132
# observation: [ 0.4603383   0.82678455 -0.11612074 -1.2063152  -0.23534009  0.18234372
#   0.0525334   0.52474356  0.        ]
# action:      3  com:no_com
# reward:      -1.5070074843860528
#
# step 133
# observation: [ 0.3452537   0.1200884  -0.15064612 -1.218324   -0.26986545  0.17033488
#   0.01800803  0.5127347   0.        ]
# action:      1  com:no_com
# reward:      -1.5223527461005626
#
# step 134
# observation: [-0.24105972  0.0900663  -0.12654014 -1.2273306  -0.24575949  0.16132826
#   0.042114    0.5037281   0.        ]
# action:      3  com:no_com
# reward:      -1.4138222978456891
#
# step 135
# observation: [-0.18079479 -0.43245026 -0.10846066 -1.1840855  -0.22768     0.20457327
#   0.06019348  0.5469731   0.        ]
# action:      3  com:no_com
# reward:      -1.222642846447973
#
# step 136
# observation: [-0.1355961  -0.8243377  -0.09490106 -1.1016518  -0.21412039  0.28700703
#   0.07375309  0.62940687  0.        ]
# action:      4  com:no_com
# reward:      -1.1949010889888796
#
# step 137
# observation: [-0.10169706 -0.11825328 -0.08473135 -1.0898265  -0.20395069  0.2988324
#   0.0839228   0.6412322   0.        ]
# action:      3  com:no_com
# reward:      -1.0688183061223182
#
# step 138
# observation: [-0.0762728  -0.58869    -0.07710407 -1.0309575  -0.19632341  0.35770136
#   0.09155007  0.7001012   0.        ]
# action:      1  com:no_com
# reward:      -0.9742427591795526
#
# step 139
# observation: [-0.5572046  -0.44151747 -0.02138361 -0.9868057  -0.14060295  0.4018531
#   0.14727053  0.7442529   0.        ]
# action:      4  com:no_com
# reward:      -1.00781385569194
#
# step 140
# observation: [-0.41790345  0.1688619   0.02040674 -1.0036919  -0.0988126   0.38496694
#   0.18906088  0.72736675  0.        ]
# action:      3  com:no_com
# reward:      -0.936522968260232
#
# step 141
# observation: [-0.3134276  -0.37335357  0.0517495  -0.9663565  -0.06746984  0.42230228
#   0.22040364  0.76470214  0.        ]
# action:      2  com:no_com
# reward:      -0.881148036587396
#
# step 142
# observation: [ 0.2649293  -0.28001517  0.02525656 -0.938355   -0.09396277  0.4503038
#   0.19391072  0.7927036   0.        ]
# action:      4  com:no_com
# reward:      -0.9358025489494985
#
# step 143
# observation: [ 0.19869699  0.2899886   0.00538687 -0.9673539  -0.11383247  0.42130494
#   0.17404102  0.7637048   0.        ]
# action:      4  com:no_com
# reward:      -1.079825643154172
#
# step 144
# observation: [ 0.14902274  0.71749145 -0.00951541 -1.039103   -0.12873475  0.3495558
#   0.15913874  0.6919556   0.        ]
# action:      2  com:no_com
# reward:      -1.199460323242466
#
# step 145
# observation: [ 0.61176705  0.5381186  -0.07069211 -1.0929149  -0.18991145  0.29574394
#   0.09796204  0.6381438   0.        ]
# action:      3  com:no_com
# reward:      -1.1870717311717918
#
# step 146
# observation: [ 0.4588253  -0.09641106 -0.11657464 -1.0832738  -0.23579398  0.30538505
#   0.05207951  0.6477849   0.        ]
# action:      1  com:no_com
# reward:      -1.168066714919029
#
# step 147
# observation: [-0.15588103 -0.07230829 -0.10098654 -1.076043   -0.22020587  0.31261587
#   0.06766761  0.6550157   0.        ]
# action:      4  com:no_com
# reward:      -1.263762482666077
#
# step 148
# observation: [-0.11691078  0.44576877 -0.08929546 -1.1206198  -0.2085148   0.268039
#   0.07935868  0.6104388   0.        ]
# action:      1  com:no_com
# reward:      -1.3327690536997467
#
# step 149
# observation: [-0.5876831   0.3343266  -0.03052715 -1.1540525  -0.14974649  0.23460634
#   0.138127    0.57700616  0.        ]
# action:      2  com:no_com
# reward:      -1.391669110983291
#
# step 150
# observation: [ 0.05923769  0.25074494 -0.03645092 -1.179127   -0.15567026  0.20953184
#   0.13220322  0.5519317   0.        ]
# action:      4  com:no_com
# reward:      -1.5590087047068122
#
# step 151
# observation: [ 0.04442827  0.68805873 -0.04089375 -1.2479329  -0.16011308  0.14072597
#   0.1277604   0.4831258   0.        ]
# action:      3  com:no_com
# reward:      -1.563299281704101
#
# step 152
# observation: [ 0.0333212   0.01604403 -0.04422587 -1.2495372  -0.1634452   0.13912156
#   0.12442828  0.4815214   0.        ]
# action:      3  com:no_com
# reward:      -1.4439611098642113
#
# step 153
# observation: [ 0.0249909  -0.48796698 -0.04672496 -1.2007406  -0.1659443   0.18791826
#   0.12192919  0.5303181   0.        ]
# action:      1  com:no_com
# reward:      -1.3552309676397285
#
# step 154
# observation: [-0.4812568  -0.36597523  0.00140072 -1.1641431  -0.11781862  0.2245158
#   0.17005487  0.56691563  0.        ]
# action:      1  com:no_com
# reward:      -1.2997306509445772
#
# step 155
# observation: [-0.8609426  -0.27448142  0.08749498 -1.1366949  -0.03172435  0.25196394
#   0.25614914  0.59436375  0.        ]
# action:      0  com:com active
# reward:      -1.3688227928959225
#
# step 156
# observation: [-0.64570695 -0.20586106  0.15206568 -1.1161088   0.03284634  0.27255005
#   0.32071984  0.6149499   2.        ]
# action:      4  com:no_com
# reward:      -1.364237345836989
#
# step 157
# observation: [-0.48428023  0.3456042   0.20049371 -1.1506692   0.08127437  0.23798962
#   0.36914784  0.58038944  0.        ]
# action:      2  com:no_com
# reward:      -1.419262639270623
#
# step 158
# observation: [ 0.13678983  0.25920314  0.18681473 -1.1765895   0.06759539  0.2120693
#   0.35546887  0.5544691   0.        ]
# action:      2  com:no_com
# reward:      -1.4465034685831355
#
# step 159
# observation: [ 0.60259235  0.19440237  0.12655549 -1.1960298   0.00733614  0.19262907
#   0.29520962  0.5350289   0.        ]
# action:      0  com:com active
# reward:      -1.5721960323229485
#
# step 160
# observation: [ 0.4519443   0.14580177  0.08136106 -1.2106099  -0.03785829  0.1780489
#   0.2500152   0.52044874  3.        ]
# action:      1  com:no_com
# reward:      -1.501671820926317
#
# step 161
# observation: [-0.1610418   0.10935133  0.09746523 -1.2215451  -0.0217541   0.16711375
#   0.2661194   0.5095136   0.        ]
# action:      4  com:no_com
# reward:      -1.6497506387053658
#
# step 162
# observation: [-0.12078134  0.5820135   0.10954337 -1.2797464  -0.00967597  0.10891241
#   0.27819753  0.45131224  0.        ]
# action:      2  com:no_com
# reward:      -1.7560869829253498
#
# step 163
# observation: [ 0.409414    0.43651012  0.06860197 -1.3233974  -0.05061737  0.06526139
#   0.23725611  0.40766123  0.        ]
# action:      3  com:no_com
# reward:      -1.7074265342449921
#
# step 164
# observation: [ 0.3070605  -0.1726174   0.03789592 -1.3061357  -0.08132342  0.08252314
#   0.20655006  0.42492297  0.        ]
# action:      2  com:no_com
# reward:      -1.6735731476438467
#
# step 165
# observation: [ 0.73029536 -0.12946306 -0.03513362 -1.2931894  -0.15435296  0.09546944
#   0.13352053  0.43786928  0.        ]
# action:      3  com:no_com
# reward:      -1.5295551001181178
#
# step 166
# observation: [ 0.5477215  -0.5970973  -0.08990577 -1.2334796  -0.20912512  0.15517917
#   0.07874838  0.497579    0.        ]
# action:      1  com:no_com
# reward:      -1.4195599542508635
#
# step 167
# observation: [-0.08920886 -0.44782296 -0.08098488 -1.1886973  -0.20020422  0.19996147
#   0.08766926  0.5423613   0.        ]
# action:      2  com:no_com
# reward:      -1.3497296269766366
#
# step 168
# observation: [ 0.43309337 -0.33586723 -0.12429422 -1.1551106  -0.24351355  0.2335482
#   0.04435993  0.575948    0.        ]
# action:      1  com:no_com
# reward:      -1.288121702919035
#
# step 169
# observation: [-0.17517997 -0.25190043 -0.10677622 -1.1299206  -0.22599556  0.25873822
#   0.06187792  0.60113806  0.        ]
# action:      0  com:com active
# reward:      -1.343151371619262
#
# step 170
# observation: [-0.13138498 -0.18892531 -0.09363772 -1.1110281  -0.21285707  0.27763078
#   0.07501642  0.6200306   3.        ]
# action:      1  com:no_com
# reward:      -1.2042402698253665
#
# step 171
# observation: [-0.59853876 -0.14169398 -0.03378385 -1.0968586  -0.15300319  0.29180017
#   0.13487029  0.6342      0.        ]
# action:      2  com:no_com
# reward:      -1.1814118140888543
#
# step 172
# observation: [ 0.05109595 -0.10627049 -0.03889344 -1.0862316  -0.15811278  0.3024272
#   0.1297607   0.64482707  0.        ]
# action:      1  com:no_com
# reward:      -1.1627004011003619
#
# step 173
# observation: [-0.46167803 -0.07970287  0.00727436 -1.0782614  -0.11194498  0.3103975
#   0.1759285   0.65279734  0.        ]
# action:      3  com:no_com
# reward:      -1.0468194068514187
#
# step 174
# observation: [-0.34625852 -0.55977714  0.04190021 -1.0222836  -0.07731913  0.3663752
#   0.21055436  0.70877504  0.        ]
# action:      0  com:com active
# reward:      -1.0655950074086786
#
# step 175
# observation: [-0.2596939  -0.41983286  0.0678696  -0.9803003  -0.05134974  0.4083585
#   0.23652375  0.75075835  3.        ]
# action:      2  com:no_com
# reward:      -0.9016406130497303
#
# step 176
# observation: [ 0.30522957 -0.31487465  0.03734665 -0.94881284 -0.08187269  0.43984598
#   0.20600079  0.7822458   0.        ]
# action:      1  com:no_com
# reward:      -0.860144343679405
#
# step 177
# observation: [-0.2710778  -0.23615599  0.06445443 -0.92519724 -0.05476491  0.46346158
#   0.23310857  0.8058614   0.        ]
# action:      2  com:no_com
# reward:      -0.8247400587333241
#
# step 178
# observation: [ 0.29669163 -0.17711699  0.03478526 -0.90748554 -0.08443408  0.48117328
#   0.20343941  0.8235731   0.        ]
# action:      2  com:no_com
# reward:      -0.8010005831158887
#
# step 179
# observation: [ 0.72251874 -0.13283774 -0.03746661 -0.8942018  -0.15668595  0.49445704
#   0.13118754  0.83685684  0.        ]
# action:      2  com:no_com
# reward:      -0.8019448169942279
#
# step 180
# observation: [ 1.0418891  -0.09962831 -0.14165552 -0.88423896 -0.26087487  0.50441986
#   0.02699863  0.8468197   0.        ]
# action:      3  com:no_com
# reward:      -0.7318542029419223
#
# step 181
# observation: [ 0.7814168  -0.5747212  -0.2197972  -0.82676685 -0.33901653  0.561892
#  -0.05114305  0.9042918   0.        ]
# action:      4  com:no_com
# reward:      -0.7725020480033484
#
# step 182
# observation: [ 0.5860626   0.06895908 -0.27840346 -0.83366275 -0.3976228   0.5549961
#  -0.1097493   0.8973959   0.        ]
# action:      1  com:no_com
# reward:      -0.7778225666160438
#
# step 183
# observation: [-0.06045306  0.05171931 -0.27235815 -0.83883464 -0.39157748  0.5498242
#  -0.103704    0.89222395  0.        ]
# action:      1  com:no_com
# reward:      -0.7576136131438561
#
# step 184
# observation: [-0.5453398   0.03878948 -0.21782416 -0.8427136  -0.3370435   0.5459452
#  -0.04917002  0.888345    0.        ]
# action:      4  com:no_com
# reward:      -0.8334422451918745
#
# step 185
# observation: [-0.40900484  0.52909213 -0.17692368 -0.89562285 -0.29614303  0.493036
#  -0.00826954  0.8354358   0.        ]
# action:      4  com:no_com
# reward:      -0.9922140006638193
#
# step 186
# observation: [-0.30675364  0.89681906 -0.14624831 -0.9853047  -0.26546764  0.40335408
#   0.02240583  0.7457539   0.        ]
# action:      4  com:no_com
# reward:      -1.2308407015303902
#
# step 187
# observation: [-0.23006523  1.1726143  -0.1232418  -1.1025661  -0.24246113  0.28609264
#   0.04541235  0.6284925   0.        ]
# action:      0  com:com active
# reward:      -1.5285526278095438
#
# step 188
# observation: [-0.17254892  0.87946075 -0.1059869  -1.1905123  -0.22520624  0.19814658
#   0.06266724  0.5405464   4.        ]
# action:      3  com:no_com
# reward:      -1.4642317116732597
#
# step 189
# observation: [-0.12941168  0.15959555 -0.09304573 -1.2064718  -0.21226507  0.18218702
#   0.07560841  0.52458686  0.        ]
# action:      2  com:no_com
# reward:      -1.502379123235535
#
# step 190
# observation: [ 0.40294123  0.11969666 -0.13333985 -1.2184415  -0.25255919  0.17021737
#   0.03531429  0.5126172   0.        ]
# action:      3  com:no_com
# reward:      -1.4130668525389476
#
# step 191
# observation: [ 0.30220592 -0.4102275  -0.16356045 -1.1774187  -0.28277978  0.21124011
#   0.0050937   0.55363995  0.        ]
# action:      2  com:no_com
# reward:      -1.3706126861723533
#
# step 192
# observation: [ 0.72665447 -0.30767062 -0.23622589 -1.1466516  -0.35544524  0.24200717
#  -0.06757175  0.584407    0.        ]
# action:      1  com:no_com
# reward:      -1.3203723422394718
#
# step 193
# observation: [ 0.04499083 -0.23075297 -0.24072498 -1.1235764  -0.3599443   0.26508248
#  -0.07207083  0.6074823   0.        ]
# action:      1  com:no_com
# reward:      -1.261507588561342
#
# step 194
# observation: [-0.4662569  -0.17306472 -0.19409929 -1.1062698  -0.31331864  0.28238896
#  -0.02544514  0.62478876  0.        ]
# action:      0  com:com active
# reward:      -1.3206054510232816
#
# step 195
# observation: [-0.34969264 -0.12979855 -0.15913002 -1.09329    -0.27834937  0.2953688
#   0.00952412  0.6377686   3.        ]
# action:      4  com:no_com
# reward:      -1.3026104772137024
#
# step 196
# observation: [-0.2622695   0.4026511  -0.13290307 -1.1335552  -0.2521224   0.25510368
#   0.03575107  0.59750354  0.        ]
# action:      3  com:no_com
# reward:      -1.2532695855112812
#
# step 197
# observation: [-0.19670212 -0.19801168 -0.11323287 -1.1137539  -0.2324522   0.27490485
#   0.05542128  0.6173047   0.        ]
# action:      3  com:no_com
# reward:      -1.1098960495117138
#
# step 198
# observation: [-0.14752659 -0.6485088  -0.0984802  -1.0489031  -0.21769954  0.33975574
#   0.07017394  0.68215555  0.        ]
# action:      2  com:no_com
# reward:      -1.0194130197080256
#
# step 199
# observation: [ 0.38935506 -0.48638156 -0.1374157  -1.0002649  -0.25663504  0.38839388
#   0.03123843  0.7307937   0.        ]
# action:      3  com:no_com
# reward:      -0.8627667732026679
#
# that all - part 4

# %% [markdown]
# ## Method Weaknesses, Issues and Failures
#
# - Adding complexity, to a complexed problem. 5 stages, all must be reasonable for a good communication model
# - sending the wrong message or too much information can result in worse performence
# - Does not worth the effort when a central 'brain' available
# - Implicit COM - domain knowlege (and ussualy obs space of other agents) dependant
# - Communication (explicit) is exposed to Noise, Jamming, and Spoofing
